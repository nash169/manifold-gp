# %% [markdown]
# # Manifold GP Semi-Supervised Learning via Precision Matrix on 1D Manifold

# %% [markdown]
# ## Preamble

# %% [markdown]
# This notebook provides an example of how to perform Gaussian Process Regression on a 1D manifold. In this example we consider a supervised learning scenario, namely the number of labeled data points is equivalent to the number of the sampled points from the underlying manifold.

# %%
import numpy as np
import torch
import gpytorch
import matplotlib.pyplot as plt
from importlib.resources import files
from manifold_gp.kernels.riemann_matern_kernel import RiemannMaternKernel
from manifold_gp.models.riemann_gp import RiemannGP

# %% [markdown]
# Select the device: GPU or CPU.

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")

# %% [markdown]
# ## Load Dataset

# %%
data_path = files('manifold_gp.data').joinpath('dumbbell.msh')
data = np.loadtxt(data_path)
sampled_x = torch.from_numpy(data[:, :2]).float().to(device)
sampled_y = torch.from_numpy(data[:, -1]).float().to(device)
(m, n) = sampled_x.shape

# %% [markdown]
# ## Apply Noise to the Dataset

# %% [markdown]
# In order to simulate real case scenario we can apply a normally distributed noise to our dataset. Here we can consider to apply the noise either to the sampled data points from the manifold or to the ground truth relative to each labeled points.

# %% [markdown]
# ### Apply noise to the manifold
# Setting the variable `manifold_noise` you can apply Gaussian noise to the sampled points from the manifold.

# %%
manifold_noise = 0.01
noisy_x = sampled_x + manifold_noise * torch.randn(m, n).to(device)

# %% [markdown]
# ### Apply noise to the ground truth
# Setting the variable `function_noise` you can apply Gaussian noise to the training points.

# %%
function_noise = 0.01
noisy_y = sampled_y + function_noise * torch.randn(m).to(device)

# %% [markdown]
# ## Training Dataset

# %% [markdown]
# Create the training dataset. You can set the variable `num_train` to define the number of points within your dataset.

# %%
num_train = 50
train_idx = torch.randperm(m)[:num_train]
train_x = noisy_x[train_idx, :]
train_y = noisy_y[train_idx]

# %% [markdown]
# ## Test Dataset

# %% [markdown]
# Create the training dataset. You can set the variable `num_test` to define the number of points within your dataset.

# %%
num_test = 10
test_idx = torch.randperm(m)[:num_test]
test_x = noisy_x[test_idx, :]
test_y = noisy_y[test_idx]

# %% [markdown]
# ## Initialize Kernel

# %% [markdown]
# Create the Riemann Matern kernel. `nu` control the kernel smoothness like in the stadard Matern kernel. `neighbors` set the number of nearest neighbors in the KNN-based discrete approximation of the Laplace-Beltrami operator and construction of differentiable eigenfunctions. `modes` set the number of the eigenfunctions used to approximate the Riemann Matern kernel. As for classical *GPyTorch* kernels the Riemann Matern kernel can be decorated using with the *ScaleKernel* to have the signal variance parameter.

# %%
nu = 2
neighbors = 5
modes = 50
kernel = gpytorch.kernels.ScaleKernel(RiemannMaternKernel(noisy_x, nu, neighbors, modes))

# %% [markdown]
# ## Initialize Likelihood and GP Model

# %% [markdown]
# Define the type of likelihood and the GP model. The GP model takes as input the training set and and labels, the likelihood and the Riemann Matern Kernel.

# %%
likelihood = gpytorch.likelihoods.GaussianLikelihood(noise_constraint=gpytorch.constraints.GreaterThan(1e-8))
model = RiemannGP(train_x, train_y, likelihood, kernel, train_idx).to(device)

# %% [markdown]
# ## Model Hyperparameters Setting

# %%
# %%capture
hypers = {
    'likelihood.noise_covar.noise': 1e-5,
    'covar_module.base_kernel.epsilon': 0.1269,
    'covar_module.base_kernel.lengthscale': 0.3133,
    'covar_module.outputscale': 0.7133,
}
model.initialize(**hypers)

# %% [markdown]
# ## Train Model

# %% [markdown]
# Train the GP model using the fast Lanczos precision matrix optimization. `lr` set the learning rate; `iters` defines the number of iteratios; `verbose` can be set to `True` for printing the parameters each iteration.

# %%
lr = 1e-1
iters = 100
verbose = True
loss = model.manifold_informed_train(lr, iters, verbose)
# Out:
# Iteration: 0, Loss: 6640.916, Noise Variance: 0.003, Signal Variance: 0.845, Lengthscale: 0.313, Epsilon: 0.127
# Iteration: 1, Loss: 4406.909, Noise Variance: 0.003, Signal Variance: 0.875, Lengthscale: 0.341, Epsilon: 0.115
# Iteration: 2, Loss: 2962.965, Noise Variance: 0.003, Signal Variance: 0.905, Lengthscale: 0.370, Epsilon: 0.105
# Iteration: 3, Loss: 2028.819, Noise Variance: 0.004, Signal Variance: 0.933, Lengthscale: 0.400, Epsilon: 0.096
# Iteration: 4, Loss: 1418.190, Noise Variance: 0.004, Signal Variance: 0.961, Lengthscale: 0.429, Epsilon: 0.088
# Iteration: 5, Loss: 1012.397, Noise Variance: 0.004, Signal Variance: 0.986, Lengthscale: 0.459, Epsilon: 0.081
# Iteration: 6, Loss: 737.340, Noise Variance: 0.004, Signal Variance: 1.010, Lengthscale: 0.487, Epsilon: 0.076
# Iteration: 7, Loss: 546.946, Noise Variance: 0.004, Signal Variance: 1.032, Lengthscale: 0.515, Epsilon: 0.071
# Iteration: 8, Loss: 412.374, Noise Variance: 0.004, Signal Variance: 1.053, Lengthscale: 0.542, Epsilon: 0.066
# Iteration: 9, Loss: 315.334, Noise Variance: 0.004, Signal Variance: 1.072, Lengthscale: 0.567, Epsilon: 0.063
# Iteration: 10, Loss: 244.032, Noise Variance: 0.004, Signal Variance: 1.090, Lengthscale: 0.592, Epsilon: 0.060
# Iteration: 11, Loss: 190.722, Noise Variance: 0.004, Signal Variance: 1.106, Lengthscale: 0.615, Epsilon: 0.057
# Iteration: 12, Loss: 150.223, Noise Variance: 0.005, Signal Variance: 1.121, Lengthscale: 0.637, Epsilon: 0.055
# Iteration: 13, Loss: 119.002, Noise Variance: 0.005, Signal Variance: 1.135, Lengthscale: 0.658, Epsilon: 0.053
# Iteration: 14, Loss: 94.609, Noise Variance: 0.005, Signal Variance: 1.147, Lengthscale: 0.678, Epsilon: 0.052
# Iteration: 15, Loss: 75.316, Noise Variance: 0.005, Signal Variance: 1.159, Lengthscale: 0.696, Epsilon: 0.051
# Iteration: 16, Loss: 59.883, Noise Variance: 0.005, Signal Variance: 1.170, Lengthscale: 0.713, Epsilon: 0.050
# Iteration: 17, Loss: 47.411, Noise Variance: 0.005, Signal Variance: 1.180, Lengthscale: 0.730, Epsilon: 0.049
# Iteration: 18, Loss: 37.235, Noise Variance: 0.005, Signal Variance: 1.190, Lengthscale: 0.745, Epsilon: 0.048
# Iteration: 19, Loss: 28.859, Noise Variance: 0.005, Signal Variance: 1.198, Lengthscale: 0.759, Epsilon: 0.048
# Iteration: 20, Loss: 21.909, Noise Variance: 0.005, Signal Variance: 1.206, Lengthscale: 0.773, Epsilon: 0.047
# Iteration: 21, Loss: 16.098, Noise Variance: 0.005, Signal Variance: 1.213, Lengthscale: 0.785, Epsilon: 0.047
# Iteration: 22, Loss: 11.206, Noise Variance: 0.005, Signal Variance: 1.220, Lengthscale: 0.797, Epsilon: 0.047
# Iteration: 23, Loss: 7.060, Noise Variance: 0.005, Signal Variance: 1.226, Lengthscale: 0.808, Epsilon: 0.047
# Iteration: 24, Loss: 3.525, Noise Variance: 0.005, Signal Variance: 1.232, Lengthscale: 0.818, Epsilon: 0.047
# Iteration: 25, Loss: 0.494, Noise Variance: 0.005, Signal Variance: 1.238, Lengthscale: 0.828, Epsilon: 0.048
# Iteration: 26, Loss: -2.118, Noise Variance: 0.005, Signal Variance: 1.243, Lengthscale: 0.837, Epsilon: 0.048
# Iteration: 27, Loss: -4.382, Noise Variance: 0.005, Signal Variance: 1.247, Lengthscale: 0.845, Epsilon: 0.048
# Iteration: 28, Loss: -6.353, Noise Variance: 0.005, Signal Variance: 1.251, Lengthscale: 0.853, Epsilon: 0.049
# Iteration: 29, Loss: -8.076, Noise Variance: 0.005, Signal Variance: 1.255, Lengthscale: 0.860, Epsilon: 0.049
# Iteration: 30, Loss: -9.589, Noise Variance: 0.005, Signal Variance: 1.259, Lengthscale: 0.867, Epsilon: 0.050
# Iteration: 31, Loss: -10.923, Noise Variance: 0.005, Signal Variance: 1.263, Lengthscale: 0.873, Epsilon: 0.050
# Iteration: 32, Loss: -12.103, Noise Variance: 0.005, Signal Variance: 1.266, Lengthscale: 0.879, Epsilon: 0.051
# Iteration: 33, Loss: -13.152, Noise Variance: 0.005, Signal Variance: 1.269, Lengthscale: 0.884, Epsilon: 0.051
# Iteration: 34, Loss: -14.087, Noise Variance: 0.005, Signal Variance: 1.271, Lengthscale: 0.889, Epsilon: 0.052
# Iteration: 35, Loss: -14.923, Noise Variance: 0.005, Signal Variance: 1.274, Lengthscale: 0.894, Epsilon: 0.053
# Iteration: 36, Loss: -15.674, Noise Variance: 0.005, Signal Variance: 1.276, Lengthscale: 0.899, Epsilon: 0.053
# Iteration: 37, Loss: -16.349, Noise Variance: 0.005, Signal Variance: 1.279, Lengthscale: 0.903, Epsilon: 0.054
# Iteration: 38, Loss: -16.959, Noise Variance: 0.005, Signal Variance: 1.281, Lengthscale: 0.907, Epsilon: 0.055
# Iteration: 39, Loss: -17.511, Noise Variance: 0.005, Signal Variance: 1.283, Lengthscale: 0.910, Epsilon: 0.056
# Iteration: 40, Loss: -18.013, Noise Variance: 0.005, Signal Variance: 1.284, Lengthscale: 0.914, Epsilon: 0.056
# Iteration: 41, Loss: -18.469, Noise Variance: 0.005, Signal Variance: 1.286, Lengthscale: 0.917, Epsilon: 0.057
# Iteration: 42, Loss: -18.887, Noise Variance: 0.005, Signal Variance: 1.288, Lengthscale: 0.920, Epsilon: 0.058
# Iteration: 43, Loss: -19.269, Noise Variance: 0.005, Signal Variance: 1.289, Lengthscale: 0.923, Epsilon: 0.059
# Iteration: 44, Loss: -19.619, Noise Variance: 0.005, Signal Variance: 1.291, Lengthscale: 0.925, Epsilon: 0.060
# Iteration: 45, Loss: -19.942, Noise Variance: 0.005, Signal Variance: 1.292, Lengthscale: 0.928, Epsilon: 0.060
# Iteration: 46, Loss: -20.241, Noise Variance: 0.005, Signal Variance: 1.293, Lengthscale: 0.930, Epsilon: 0.061
# Iteration: 47, Loss: -20.516, Noise Variance: 0.005, Signal Variance: 1.294, Lengthscale: 0.933, Epsilon: 0.062
# Iteration: 48, Loss: -20.772, Noise Variance: 0.005, Signal Variance: 1.296, Lengthscale: 0.935, Epsilon: 0.063
# Iteration: 49, Loss: -21.010, Noise Variance: 0.005, Signal Variance: 1.297, Lengthscale: 0.937, Epsilon: 0.064
# Iteration: 50, Loss: -21.232, Noise Variance: 0.005, Signal Variance: 1.298, Lengthscale: 0.939, Epsilon: 0.064
# Iteration: 51, Loss: -21.439, Noise Variance: 0.005, Signal Variance: 1.299, Lengthscale: 0.940, Epsilon: 0.065
# Iteration: 52, Loss: -21.634, Noise Variance: 0.005, Signal Variance: 1.299, Lengthscale: 0.942, Epsilon: 0.066
# Iteration: 53, Loss: -21.816, Noise Variance: 0.005, Signal Variance: 1.300, Lengthscale: 0.944, Epsilon: 0.067
# Iteration: 54, Loss: -21.988, Noise Variance: 0.005, Signal Variance: 1.301, Lengthscale: 0.945, Epsilon: 0.067
# Iteration: 55, Loss: -22.150, Noise Variance: 0.005, Signal Variance: 1.302, Lengthscale: 0.947, Epsilon: 0.068
# Iteration: 56, Loss: -22.303, Noise Variance: 0.005, Signal Variance: 1.303, Lengthscale: 0.948, Epsilon: 0.069
# Iteration: 57, Loss: -22.449, Noise Variance: 0.005, Signal Variance: 1.304, Lengthscale: 0.950, Epsilon: 0.070
# Iteration: 58, Loss: -22.587, Noise Variance: 0.005, Signal Variance: 1.304, Lengthscale: 0.951, Epsilon: 0.070
# Iteration: 59, Loss: -22.718, Noise Variance: 0.005, Signal Variance: 1.305, Lengthscale: 0.952, Epsilon: 0.071
# Iteration: 60, Loss: -22.843, Noise Variance: 0.005, Signal Variance: 1.306, Lengthscale: 0.954, Epsilon: 0.072
# Iteration: 61, Loss: -22.963, Noise Variance: 0.005, Signal Variance: 1.306, Lengthscale: 0.955, Epsilon: 0.072
# Iteration: 62, Loss: -23.078, Noise Variance: 0.005, Signal Variance: 1.307, Lengthscale: 0.956, Epsilon: 0.073
# Iteration: 63, Loss: -23.188, Noise Variance: 0.005, Signal Variance: 1.308, Lengthscale: 0.957, Epsilon: 0.073
# Iteration: 64, Loss: -23.293, Noise Variance: 0.005, Signal Variance: 1.308, Lengthscale: 0.958, Epsilon: 0.074
# Iteration: 65, Loss: -23.395, Noise Variance: 0.005, Signal Variance: 1.309, Lengthscale: 0.960, Epsilon: 0.075
# Iteration: 66, Loss: -23.494, Noise Variance: 0.005, Signal Variance: 1.309, Lengthscale: 0.961, Epsilon: 0.075
# Iteration: 67, Loss: -23.589, Noise Variance: 0.005, Signal Variance: 1.310, Lengthscale: 0.962, Epsilon: 0.076
# Iteration: 68, Loss: -23.681, Noise Variance: 0.005, Signal Variance: 1.310, Lengthscale: 0.963, Epsilon: 0.076
# Iteration: 69, Loss: -23.770, Noise Variance: 0.005, Signal Variance: 1.311, Lengthscale: 0.964, Epsilon: 0.077
# Iteration: 70, Loss: -23.856, Noise Variance: 0.005, Signal Variance: 1.312, Lengthscale: 0.965, Epsilon: 0.077
# Iteration: 71, Loss: -23.940, Noise Variance: 0.005, Signal Variance: 1.312, Lengthscale: 0.966, Epsilon: 0.077
# Iteration: 72, Loss: -24.022, Noise Variance: 0.005, Signal Variance: 1.313, Lengthscale: 0.967, Epsilon: 0.078
# Iteration: 73, Loss: -24.102, Noise Variance: 0.005, Signal Variance: 1.313, Lengthscale: 0.968, Epsilon: 0.078
# Iteration: 74, Loss: -24.180, Noise Variance: 0.005, Signal Variance: 1.314, Lengthscale: 0.968, Epsilon: 0.079
# Iteration: 75, Loss: -24.256, Noise Variance: 0.005, Signal Variance: 1.314, Lengthscale: 0.969, Epsilon: 0.079
# Iteration: 76, Loss: -24.330, Noise Variance: 0.005, Signal Variance: 1.315, Lengthscale: 0.970, Epsilon: 0.079
# Iteration: 77, Loss: -24.402, Noise Variance: 0.005, Signal Variance: 1.315, Lengthscale: 0.971, Epsilon: 0.080
# Iteration: 78, Loss: -24.474, Noise Variance: 0.005, Signal Variance: 1.316, Lengthscale: 0.972, Epsilon: 0.080
# Iteration: 79, Loss: -24.543, Noise Variance: 0.005, Signal Variance: 1.316, Lengthscale: 0.973, Epsilon: 0.080
# Iteration: 80, Loss: -24.612, Noise Variance: 0.005, Signal Variance: 1.316, Lengthscale: 0.974, Epsilon: 0.080
# Iteration: 81, Loss: -24.679, Noise Variance: 0.005, Signal Variance: 1.317, Lengthscale: 0.975, Epsilon: 0.081
# Iteration: 82, Loss: -24.745, Noise Variance: 0.005, Signal Variance: 1.317, Lengthscale: 0.976, Epsilon: 0.081
# Iteration: 83, Loss: -24.809, Noise Variance: 0.005, Signal Variance: 1.318, Lengthscale: 0.976, Epsilon: 0.081
# Iteration: 84, Loss: -24.873, Noise Variance: 0.005, Signal Variance: 1.318, Lengthscale: 0.977, Epsilon: 0.081
# Iteration: 85, Loss: -24.936, Noise Variance: 0.005, Signal Variance: 1.319, Lengthscale: 0.978, Epsilon: 0.081
# Iteration: 86, Loss: -24.997, Noise Variance: 0.005, Signal Variance: 1.319, Lengthscale: 0.979, Epsilon: 0.082
# Iteration: 87, Loss: -25.058, Noise Variance: 0.005, Signal Variance: 1.320, Lengthscale: 0.980, Epsilon: 0.082
# Iteration: 88, Loss: -25.117, Noise Variance: 0.005, Signal Variance: 1.320, Lengthscale: 0.981, Epsilon: 0.082
# Iteration: 89, Loss: -25.176, Noise Variance: 0.005, Signal Variance: 1.321, Lengthscale: 0.981, Epsilon: 0.082
# Iteration: 90, Loss: -25.234, Noise Variance: 0.005, Signal Variance: 1.321, Lengthscale: 0.982, Epsilon: 0.082
# Iteration: 91, Loss: -25.291, Noise Variance: 0.005, Signal Variance: 1.321, Lengthscale: 0.983, Epsilon: 0.082
# Iteration: 92, Loss: -25.347, Noise Variance: 0.005, Signal Variance: 1.322, Lengthscale: 0.984, Epsilon: 0.082
# Iteration: 93, Loss: -25.403, Noise Variance: 0.005, Signal Variance: 1.322, Lengthscale: 0.985, Epsilon: 0.082
# Iteration: 94, Loss: -25.458, Noise Variance: 0.005, Signal Variance: 1.323, Lengthscale: 0.985, Epsilon: 0.082
# Iteration: 95, Loss: -25.512, Noise Variance: 0.005, Signal Variance: 1.323, Lengthscale: 0.986, Epsilon: 0.082
# Iteration: 96, Loss: -25.565, Noise Variance: 0.005, Signal Variance: 1.324, Lengthscale: 0.987, Epsilon: 0.082
# Iteration: 97, Loss: -25.617, Noise Variance: 0.005, Signal Variance: 1.324, Lengthscale: 0.988, Epsilon: 0.082
# Iteration: 98, Loss: -25.669, Noise Variance: 0.005, Signal Variance: 1.324, Lengthscale: 0.989, Epsilon: 0.083
# Iteration: 99, Loss: -25.720, Noise Variance: 0.005, Signal Variance: 1.325, Lengthscale: 0.989, Epsilon: 0.083

# %% [markdown]
# ## Model Evaluation

# %%
# %%capture
likelihood.eval()
model.eval()

# %% [markdown]
# Getting faster predictive distributions using [LOVE](https://arxiv.org/abs/1803.06058). We compute the **mean**, the **standard deviation** and one **posterior sample**. In addition we evaluate the kernel at the first point of our dataset.

# %%
# %%capture
with torch.no_grad():
    preds = likelihood(model(noisy_x))
    mean = preds.mean
    std = preds.stddev
    posterior_sample = preds.sample()
    kernel_eval = kernel(sampled_x[0, :].unsqueeze(0), sampled_x).evaluate().squeeze()

# %% [markdown]
# ## Plot

# %% [markdown]
# Plot the results.

# %%
with torch.no_grad():
    fig = plt.figure(figsize=(17, 9))

    # Bring data to cpu
    if use_cuda:
        sampled_x = sampled_x.cpu()
        sampled_y = sampled_y.cpu()
        train_x = train_x.cpu()
        test_x = test_x.cpu()
        kernel_eval = kernel_eval.cpu()
        posterior_sample = posterior_sample.cpu()
        mean = mean.cpu()
        std = std.cpu()

    # Sampled Points
    ax = fig.add_subplot(231)
    ax.scatter(sampled_x[:, 0], sampled_x[:, 1])
    ax.scatter(train_x[:, 0], train_x[:, 1], c="r", edgecolors="r")
    ax.scatter(test_x[:, 0], test_x[:, 1], c="y", edgecolors="y")
    ax.axis('equal')
    ax.set_title('Training Points')

    # Ground Truth
    ax = fig.add_subplot(232)
    plot = ax.scatter(sampled_x[:, 0], sampled_x[:, 1],
                      c=sampled_y, vmin=-0.5, vmax=0.5)
    fig.colorbar(plot)
    ax.axis('equal')
    ax.set_title('Ground Truth')

    # Kernel evaluation
    ax = fig.add_subplot(233)
    plot = ax.scatter(sampled_x[:, 0], sampled_x[:, 1], c=kernel_eval)
    ax.scatter(sampled_x[0, 0], sampled_x[0, 1], c='k')
    fig.colorbar(plot)
    ax.axis('equal')
    ax.set_title('Kernel Evaluation')

    # One Posterior Sample
    ax = fig.add_subplot(234)
    plot = ax.scatter(sampled_x[:, 0], sampled_x[:, 1], c=posterior_sample)
    fig.colorbar(plot)
    ax.axis('equal')
    ax.set_title('One Posterior Sample')

    # Mean
    ax = fig.add_subplot(235)
    plot = ax.scatter(sampled_x[:, 0], sampled_x[:, 1],
                      c=mean, vmin=-0.5, vmax=0.5)
    fig.colorbar(plot)
    ax.axis('equal')
    ax.set_title('Mean')

    # Standard Deviation
    ax = fig.add_subplot(236)
    plot = ax.scatter(sampled_x[:, 0], sampled_x[:, 1], c=std)
    fig.colorbar(plot)
    ax.axis('equal')
    ax.set_title('Standard Deviation')
