# %% [markdown]
# # IMGP - Supervised Learning - RMNIST

# %% [markdown]
# ## Preamble

# %% [markdown]
# This notebook provides an example of how to perform Gaussian Process Regression on a 1D manifold. In this example we consider a supervised learning scenario, namely the number of labeled data points is equivalent to the number of the sampled points from the underlying manifold.

# %%
import math
import torch
import gpytorch
import numpy as np

# %matplotlib widget
import matplotlib.pyplot as plt

from manifold_gp.kernels import RiemannMaternKernel
from manifold_gp.models import RiemannGP, VanillaGP
from manifold_gp.utils import rmnist_dataset, vanilla_train, manifold_informed_train, test_model, NearestNeighbors
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ## Dataset

# %%
num_train = 0.01
scaling, single_digit, regenerate = True, True, False, 
normalize_x, normalize_y = False, True
graphbandwidth_constraint, graphbandwidth_prior = True, False
load_manifold_model, load_vanilla_model = False, True
train_manifold_model, train_vanilla_model = True, False
save_manifold_model, save_vanilla_model = True, True

# %%
train_x, train_y, _, test_x, test_y, _ = rmnist_dataset(scaling=scaling, single_digit=single_digit, regenerate=regenerate)
torch.manual_seed(1337)
train_idx = torch.zeros(train_x.shape[0]).scatter_(0, torch.randperm(train_x.shape[0])[:int(num_train*train_x.shape[0])], 1).bool()

use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
train_x, train_y = train_x[train_idx].contiguous().to(device).flatten(start_dim=1), train_y[train_idx].contiguous().to(device)
test_x, test_y = test_x.contiguous().to(device).flatten(start_dim=1), test_y.contiguous().to(device)

if normalize_x:
    mu_x, std_x = train_x.mean(dim=-2, keepdim=True), train_x.std(dim=-2, keepdim=True) + 1e-6
    train_x.sub_(mu_x).div_(std_x)
    test_x.sub_(mu_x).div_(std_x)
if normalize_y:
    mu_y, std_y = train_y.mean(), train_y.std()
    train_y.sub_(mu_y).div_(std_y)
    test_y.sub_(mu_y).div_(std_y)
# Out:
# Loading SRMNIST

# %%
if graphbandwidth_constraint or graphbandwidth_prior:
    knn = NearestNeighbors(train_x, nlist=1)
    edge_values = knn.search(train_x, 10)[0][:, 1:]
    
    graphbandwidth_min = edge_values[:,0].max().div(-4*math.log(1e-4)).sqrt()
    median = edge_values.sqrt().mean(dim=1).sort()[0][int(round(edge_values.shape[0]*0.50))]
    gamma_rate = 4*median/(median-graphbandwidth_min)**2
    gamma_concentration = gamma_rate * median + 1
    
    del knn, edge_values

# %% [markdown]
# ## Model

# %%
# %%capture
model_vanilla = VanillaGP(
    train_x, 
    train_y, 
    gpytorch.likelihoods.GaussianLikelihood(), 
    gpytorch.kernels.ScaleKernel(gpytorch.kernels.RBFKernel())
).to(device)

hypers_vanilla = {
    'likelihood.noise_covar.noise': 1e-2,
    'covar_module.base_kernel.lengthscale': 1.0,
    'covar_module.outputscale': 1.0,
}
model_vanilla.initialize(**hypers_vanilla)

# %%
# %%capture
likelihood = gpytorch.likelihoods.GaussianLikelihood(
    noise_constraint=gpytorch.constraints.GreaterThan(1e-8),
)

kernel = gpytorch.kernels.ScaleKernel(
    RiemannMaternKernel(
        nu=2,
        x=train_x,
        nearest_neighbors=50,
        laplacian_normalization="randomwalk",
        num_modes=50,
        bump_scale=10.0,
        bump_decay=1.0,
        graphbandwidth_constraint=gpytorch.constraints.GreaterThan(graphbandwidth_min) if graphbandwidth_constraint else None,
        graphbandwidth_prior=gpytorch.priors.GammaPrior(gamma_concentration, gamma_rate) if graphbandwidth_prior else None
    )
)

model = RiemannGP(train_x, train_y, likelihood, kernel).to(device)

hypers = {
    'likelihood.noise_covar.noise': 1e-2,
    'covar_module.base_kernel.graphbandwidth': kernel.base_kernel.graphbandwidth_prior.sample() if graphbandwidth_prior else 2.0,
    'covar_module.base_kernel.lengthscale': 1.0,
    'covar_module.outputscale': 1.0,
}
model.initialize(**hypers)

# %% [markdown]
# ## Train

# %%
if load_manifold_model:
    model.load_state_dict(torch.load('../models/srmnist_manifold_supervised.pth' if single_digit else '../models/rmnist_manifold_supervised.pth'))
if train_manifold_model:
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-1, weight_decay=0.0)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=100, threshold=1e-3, 
                                                                threshold_mode='rel', cooldown=0, min_lr=0, eps=1e-8, verbose=True)
    loss = manifold_informed_train(model, optimizer, max_iter=500, tolerance=1e-2, update_norm=100, num_rand_vec=100,
                                   max_cholesky=1000, cg_tolerance=1e-2, cg_max_iter=1000, scheduler=scheduler, verbose=True)
    if save_manifold_model:
        torch.save(model.state_dict(), '../models/srmnist_manifold_supervised.pth' if single_digit else '../models/rmnist_manifold_supervised.pth')
# Out:
# /home/bernardo/.local/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:46: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Iteration: 0, Loss: 1471.668, Lr: 0.1,	Noise Variance: 0.010,	Signal Variance: 6.257,	Lengthscale: 1.000, Graphbandwidth: 2.000
# Iteration: 1, Loss: 1082.387, Lr: 0.1,	Noise Variance: 0.011,	Signal Variance: 6.157,	Lengthscale: 1.064, Graphbandwidth: 2.046
# Iteration: 2, Loss: 820.061, Lr: 0.1,	Noise Variance: 0.012,	Signal Variance: 6.061,	Lengthscale: 1.129, Graphbandwidth: 2.094
# Iteration: 3, Loss: 633.151, Lr: 0.1,	Noise Variance: 0.013,	Signal Variance: 5.967,	Lengthscale: 1.192, Graphbandwidth: 2.142
# Iteration: 4, Loss: 497.296, Lr: 0.1,	Noise Variance: 0.014,	Signal Variance: 5.877,	Lengthscale: 1.254, Graphbandwidth: 2.191
# Iteration: 5, Loss: 397.917, Lr: 0.1,	Noise Variance: 0.016,	Signal Variance: 5.792,	Lengthscale: 1.314, Graphbandwidth: 2.241
# Iteration: 6, Loss: 325.132, Lr: 0.1,	Noise Variance: 0.017,	Signal Variance: 5.711,	Lengthscale: 1.372, Graphbandwidth: 2.291
# Iteration: 7, Loss: 271.873, Lr: 0.1,	Noise Variance: 0.019,	Signal Variance: 5.634,	Lengthscale: 1.427, Graphbandwidth: 2.340
# Iteration: 8, Loss: 232.982, Lr: 0.1,	Noise Variance: 0.020,	Signal Variance: 5.562,	Lengthscale: 1.480, Graphbandwidth: 2.389
# Iteration: 9, Loss: 204.675, Lr: 0.1,	Noise Variance: 0.022,	Signal Variance: 5.494,	Lengthscale: 1.529, Graphbandwidth: 2.437
# Iteration: 10, Loss: 184.166, Lr: 0.1,	Noise Variance: 0.023,	Signal Variance: 5.430,	Lengthscale: 1.575, Graphbandwidth: 2.483
# Iteration: 11, Loss: 169.406, Lr: 0.1,	Noise Variance: 0.024,	Signal Variance: 5.371,	Lengthscale: 1.619, Graphbandwidth: 2.528
# Iteration: 12, Loss: 158.882, Lr: 0.1,	Noise Variance: 0.026,	Signal Variance: 5.316,	Lengthscale: 1.659, Graphbandwidth: 2.570
# Iteration: 13, Loss: 151.479, Lr: 0.1,	Noise Variance: 0.027,	Signal Variance: 5.265,	Lengthscale: 1.697, Graphbandwidth: 2.611
# Iteration: 14, Loss: 146.373, Lr: 0.1,	Noise Variance: 0.029,	Signal Variance: 5.217,	Lengthscale: 1.732, Graphbandwidth: 2.649
# Iteration: 15, Loss: 142.953, Lr: 0.1,	Noise Variance: 0.030,	Signal Variance: 5.174,	Lengthscale: 1.764, Graphbandwidth: 2.685
# Iteration: 16, Loss: 140.765, Lr: 0.1,	Noise Variance: 0.031,	Signal Variance: 5.134,	Lengthscale: 1.794, Graphbandwidth: 2.719
# Iteration: 17, Loss: 139.474, Lr: 0.1,	Noise Variance: 0.032,	Signal Variance: 5.097,	Lengthscale: 1.822, Graphbandwidth: 2.750
# Iteration: 18, Loss: 138.828, Lr: 0.1,	Noise Variance: 0.033,	Signal Variance: 5.063,	Lengthscale: 1.847, Graphbandwidth: 2.779
# Iteration: 19, Loss: 138.640, Lr: 0.1,	Noise Variance: 0.034,	Signal Variance: 5.033,	Lengthscale: 1.870, Graphbandwidth: 2.806
# Iteration: 20, Loss: 138.771, Lr: 0.1,	Noise Variance: 0.035,	Signal Variance: 5.005,	Lengthscale: 1.891, Graphbandwidth: 2.830
# Iteration: 21, Loss: 139.116, Lr: 0.1,	Noise Variance: 0.036,	Signal Variance: 4.979,	Lengthscale: 1.911, Graphbandwidth: 2.852
# Iteration: 22, Loss: 139.599, Lr: 0.1,	Noise Variance: 0.037,	Signal Variance: 4.957,	Lengthscale: 1.928, Graphbandwidth: 2.872
# Iteration: 23, Loss: 140.162, Lr: 0.1,	Noise Variance: 0.038,	Signal Variance: 4.936,	Lengthscale: 1.944, Graphbandwidth: 2.890
# Iteration: 24, Loss: 140.762, Lr: 0.1,	Noise Variance: 0.038,	Signal Variance: 4.918,	Lengthscale: 1.958, Graphbandwidth: 2.906
# Iteration: 25, Loss: 141.369, Lr: 0.1,	Noise Variance: 0.039,	Signal Variance: 4.902,	Lengthscale: 1.971, Graphbandwidth: 2.920
# Iteration: 26, Loss: 141.961, Lr: 0.1,	Noise Variance: 0.040,	Signal Variance: 4.887,	Lengthscale: 1.983, Graphbandwidth: 2.933
# Iteration: 27, Loss: 142.521, Lr: 0.1,	Noise Variance: 0.040,	Signal Variance: 4.875,	Lengthscale: 1.994, Graphbandwidth: 2.943
# Iteration: 28, Loss: 143.038, Lr: 0.1,	Noise Variance: 0.041,	Signal Variance: 4.864,	Lengthscale: 2.003, Graphbandwidth: 2.952
# Iteration: 29, Loss: 143.506, Lr: 0.1,	Noise Variance: 0.041,	Signal Variance: 4.855,	Lengthscale: 2.011, Graphbandwidth: 2.960
# Iteration: 30, Loss: 143.919, Lr: 0.1,	Noise Variance: 0.041,	Signal Variance: 4.847,	Lengthscale: 2.018, Graphbandwidth: 2.966
# Iteration: 31, Loss: 144.277, Lr: 0.1,	Noise Variance: 0.042,	Signal Variance: 4.841,	Lengthscale: 2.025, Graphbandwidth: 2.971
# Iteration: 32, Loss: 144.578, Lr: 0.1,	Noise Variance: 0.042,	Signal Variance: 4.835,	Lengthscale: 2.030, Graphbandwidth: 2.975
# Iteration: 33, Loss: 144.824, Lr: 0.1,	Noise Variance: 0.042,	Signal Variance: 4.831,	Lengthscale: 2.035, Graphbandwidth: 2.977
# Iteration: 34, Loss: 145.015, Lr: 0.1,	Noise Variance: 0.043,	Signal Variance: 4.828,	Lengthscale: 2.039, Graphbandwidth: 2.979
# Iteration: 35, Loss: 145.154, Lr: 0.1,	Noise Variance: 0.043,	Signal Variance: 4.827,	Lengthscale: 2.042, Graphbandwidth: 2.979
# Iteration: 36, Loss: 145.243, Lr: 0.1,	Noise Variance: 0.043,	Signal Variance: 4.826,	Lengthscale: 2.045, Graphbandwidth: 2.979
# Iteration: 37, Loss: 145.287, Lr: 0.1,	Noise Variance: 0.043,	Signal Variance: 4.826,	Lengthscale: 2.047, Graphbandwidth: 2.977
# Iteration: 38, Loss: 145.287, Lr: 0.1,	Noise Variance: 0.043,	Signal Variance: 4.826,	Lengthscale: 2.048, Graphbandwidth: 2.975
# Iteration: 39, Loss: 145.247, Lr: 0.1,	Noise Variance: 0.043,	Signal Variance: 4.828,	Lengthscale: 2.049, Graphbandwidth: 2.972
# Iteration: 40, Loss: 145.170, Lr: 0.1,	Noise Variance: 0.044,	Signal Variance: 4.830,	Lengthscale: 2.050, Graphbandwidth: 2.969
# Iteration: 41, Loss: 145.061, Lr: 0.1,	Noise Variance: 0.044,	Signal Variance: 4.833,	Lengthscale: 2.050, Graphbandwidth: 2.965
# Iteration: 42, Loss: 144.921, Lr: 0.1,	Noise Variance: 0.044,	Signal Variance: 4.836,	Lengthscale: 2.050, Graphbandwidth: 2.960
# Iteration: 43, Loss: 144.755, Lr: 0.1,	Noise Variance: 0.044,	Signal Variance: 4.840,	Lengthscale: 2.050, Graphbandwidth: 2.955
# Iteration: 44, Loss: 144.566, Lr: 0.1,	Noise Variance: 0.044,	Signal Variance: 4.845,	Lengthscale: 2.049, Graphbandwidth: 2.949
# Iteration: 45, Loss: 144.357, Lr: 0.1,	Noise Variance: 0.044,	Signal Variance: 4.850,	Lengthscale: 2.048, Graphbandwidth: 2.943
# Iteration: 46, Loss: 144.130, Lr: 0.1,	Noise Variance: 0.044,	Signal Variance: 4.855,	Lengthscale: 2.047, Graphbandwidth: 2.936
# Iteration: 47, Loss: 143.888, Lr: 0.1,	Noise Variance: 0.044,	Signal Variance: 4.860,	Lengthscale: 2.045, Graphbandwidth: 2.930
# Iteration: 48, Loss: 143.635, Lr: 0.1,	Noise Variance: 0.044,	Signal Variance: 4.866,	Lengthscale: 2.044, Graphbandwidth: 2.922
# Iteration: 49, Loss: 143.373, Lr: 0.1,	Noise Variance: 0.044,	Signal Variance: 4.872,	Lengthscale: 2.042, Graphbandwidth: 2.915
# Iteration: 50, Loss: 143.104, Lr: 0.1,	Noise Variance: 0.044,	Signal Variance: 4.879,	Lengthscale: 2.040, Graphbandwidth: 2.907
# Iteration: 51, Loss: 142.830, Lr: 0.1,	Noise Variance: 0.044,	Signal Variance: 4.885,	Lengthscale: 2.038, Graphbandwidth: 2.900
# Iteration: 52, Loss: 142.554, Lr: 0.1,	Noise Variance: 0.044,	Signal Variance: 4.892,	Lengthscale: 2.035, Graphbandwidth: 2.892
# Iteration: 53, Loss: 142.277, Lr: 0.1,	Noise Variance: 0.044,	Signal Variance: 4.899,	Lengthscale: 2.033, Graphbandwidth: 2.883
# Iteration: 54, Loss: 142.002, Lr: 0.1,	Noise Variance: 0.044,	Signal Variance: 4.906,	Lengthscale: 2.030, Graphbandwidth: 2.875
# Iteration: 55, Loss: 141.729, Lr: 0.1,	Noise Variance: 0.044,	Signal Variance: 4.913,	Lengthscale: 2.028, Graphbandwidth: 2.867
# Iteration: 56, Loss: 141.461, Lr: 0.1,	Noise Variance: 0.044,	Signal Variance: 4.920,	Lengthscale: 2.025, Graphbandwidth: 2.858
# Iteration: 57, Loss: 141.199, Lr: 0.1,	Noise Variance: 0.044,	Signal Variance: 4.928,	Lengthscale: 2.023, Graphbandwidth: 2.850
# Iteration: 58, Loss: 140.944, Lr: 0.1,	Noise Variance: 0.044,	Signal Variance: 4.935,	Lengthscale: 2.020, Graphbandwidth: 2.841
# Iteration: 59, Loss: 140.698, Lr: 0.1,	Noise Variance: 0.043,	Signal Variance: 4.942,	Lengthscale: 2.017, Graphbandwidth: 2.833
# Iteration: 60, Loss: 140.460, Lr: 0.1,	Noise Variance: 0.043,	Signal Variance: 4.949,	Lengthscale: 2.015, Graphbandwidth: 2.825
# Iteration: 61, Loss: 140.232, Lr: 0.1,	Noise Variance: 0.043,	Signal Variance: 4.956,	Lengthscale: 2.012, Graphbandwidth: 2.816
# Iteration: 62, Loss: 140.015, Lr: 0.1,	Noise Variance: 0.043,	Signal Variance: 4.964,	Lengthscale: 2.009, Graphbandwidth: 2.808
# Iteration: 63, Loss: 139.809, Lr: 0.1,	Noise Variance: 0.043,	Signal Variance: 4.971,	Lengthscale: 2.007, Graphbandwidth: 2.800
# Iteration: 64, Loss: 139.614, Lr: 0.1,	Noise Variance: 0.043,	Signal Variance: 4.977,	Lengthscale: 2.004, Graphbandwidth: 2.792
# Iteration: 65, Loss: 139.430, Lr: 0.1,	Noise Variance: 0.043,	Signal Variance: 4.984,	Lengthscale: 2.002, Graphbandwidth: 2.784
# Iteration: 66, Loss: 139.259, Lr: 0.1,	Noise Variance: 0.043,	Signal Variance: 4.991,	Lengthscale: 1.999, Graphbandwidth: 2.776
# Iteration: 67, Loss: 139.099, Lr: 0.1,	Noise Variance: 0.043,	Signal Variance: 4.997,	Lengthscale: 1.997, Graphbandwidth: 2.768
# Iteration: 68, Loss: 138.951, Lr: 0.1,	Noise Variance: 0.043,	Signal Variance: 5.004,	Lengthscale: 1.994, Graphbandwidth: 2.760
# Iteration: 69, Loss: 138.815, Lr: 0.1,	Noise Variance: 0.043,	Signal Variance: 5.010,	Lengthscale: 1.992, Graphbandwidth: 2.753
# Iteration: 70, Loss: 138.690, Lr: 0.1,	Noise Variance: 0.043,	Signal Variance: 5.016,	Lengthscale: 1.990, Graphbandwidth: 2.746
# Iteration: 71, Loss: 138.575, Lr: 0.1,	Noise Variance: 0.042,	Signal Variance: 5.022,	Lengthscale: 1.988, Graphbandwidth: 2.739
# Iteration: 72, Loss: 138.472, Lr: 0.1,	Noise Variance: 0.042,	Signal Variance: 5.027,	Lengthscale: 1.986, Graphbandwidth: 2.732
# Iteration: 73, Loss: 138.378, Lr: 0.1,	Noise Variance: 0.042,	Signal Variance: 5.033,	Lengthscale: 1.984, Graphbandwidth: 2.725
# Iteration: 74, Loss: 138.294, Lr: 0.1,	Noise Variance: 0.042,	Signal Variance: 5.038,	Lengthscale: 1.982, Graphbandwidth: 2.719
# Iteration: 75, Loss: 138.219, Lr: 0.1,	Noise Variance: 0.042,	Signal Variance: 5.043,	Lengthscale: 1.980, Graphbandwidth: 2.713
# Iteration: 76, Loss: 138.153, Lr: 0.1,	Noise Variance: 0.042,	Signal Variance: 5.048,	Lengthscale: 1.978, Graphbandwidth: 2.707
# Iteration: 77, Loss: 138.094, Lr: 0.1,	Noise Variance: 0.042,	Signal Variance: 5.053,	Lengthscale: 1.977, Graphbandwidth: 2.701
# Iteration: 78, Loss: 138.043, Lr: 0.1,	Noise Variance: 0.042,	Signal Variance: 5.057,	Lengthscale: 1.975, Graphbandwidth: 2.695
# Iteration: 79, Loss: 137.998, Lr: 0.1,	Noise Variance: 0.042,	Signal Variance: 5.061,	Lengthscale: 1.974, Graphbandwidth: 2.690
# Iteration: 80, Loss: 137.959, Lr: 0.1,	Noise Variance: 0.042,	Signal Variance: 5.065,	Lengthscale: 1.973, Graphbandwidth: 2.685
# Iteration: 81, Loss: 137.925, Lr: 0.1,	Noise Variance: 0.042,	Signal Variance: 5.069,	Lengthscale: 1.972, Graphbandwidth: 2.680
# Iteration: 82, Loss: 137.896, Lr: 0.1,	Noise Variance: 0.042,	Signal Variance: 5.072,	Lengthscale: 1.971, Graphbandwidth: 2.675
# Iteration: 83, Loss: 137.872, Lr: 0.1,	Noise Variance: 0.042,	Signal Variance: 5.075,	Lengthscale: 1.970, Graphbandwidth: 2.671
# Iteration: 84, Loss: 137.851, Lr: 0.1,	Noise Variance: 0.042,	Signal Variance: 5.078,	Lengthscale: 1.969, Graphbandwidth: 2.666
# Iteration: 85, Loss: 137.833, Lr: 0.1,	Noise Variance: 0.041,	Signal Variance: 5.081,	Lengthscale: 1.968, Graphbandwidth: 2.662
# Iteration: 86, Loss: 137.818, Lr: 0.1,	Noise Variance: 0.041,	Signal Variance: 5.084,	Lengthscale: 1.968, Graphbandwidth: 2.658
# Iteration: 87, Loss: 137.805, Lr: 0.1,	Noise Variance: 0.041,	Signal Variance: 5.086,	Lengthscale: 1.967, Graphbandwidth: 2.655
# Iteration: 88, Loss: 137.794, Lr: 0.1,	Noise Variance: 0.041,	Signal Variance: 5.088,	Lengthscale: 1.967, Graphbandwidth: 2.651
# Iteration: 89, Loss: 137.785, Lr: 0.1,	Noise Variance: 0.041,	Signal Variance: 5.090,	Lengthscale: 1.967, Graphbandwidth: 2.648
# Iteration: 90, Loss: 137.777, Lr: 0.1,	Noise Variance: 0.041,	Signal Variance: 5.092,	Lengthscale: 1.966, Graphbandwidth: 2.645
# Iteration: 91, Loss: 137.769, Lr: 0.1,	Noise Variance: 0.041,	Signal Variance: 5.094,	Lengthscale: 1.966, Graphbandwidth: 2.642
# Iteration: 92, Loss: 137.762, Lr: 0.1,	Noise Variance: 0.041,	Signal Variance: 5.095,	Lengthscale: 1.966, Graphbandwidth: 2.639
# Iteration: 93, Loss: 137.756, Lr: 0.1,	Noise Variance: 0.041,	Signal Variance: 5.097,	Lengthscale: 1.966, Graphbandwidth: 2.637
# Iteration: 94, Loss: 137.749, Lr: 0.1,	Noise Variance: 0.041,	Signal Variance: 5.098,	Lengthscale: 1.967, Graphbandwidth: 2.634
# Iteration: 95, Loss: 137.743, Lr: 0.1,	Noise Variance: 0.041,	Signal Variance: 5.099,	Lengthscale: 1.967, Graphbandwidth: 2.632
# Iteration: 96, Loss: 137.737, Lr: 0.1,	Noise Variance: 0.041,	Signal Variance: 5.099,	Lengthscale: 1.967, Graphbandwidth: 2.630
# Iteration: 97, Loss: 137.731, Lr: 0.1,	Noise Variance: 0.041,	Signal Variance: 5.100,	Lengthscale: 1.968, Graphbandwidth: 2.628
# Iteration: 98, Loss: 137.724, Lr: 0.1,	Noise Variance: 0.041,	Signal Variance: 5.101,	Lengthscale: 1.968, Graphbandwidth: 2.626
# Iteration: 99, Loss: 137.717, Lr: 0.1,	Noise Variance: 0.041,	Signal Variance: 5.101,	Lengthscale: 1.969, Graphbandwidth: 2.624
# Iteration: 100, Loss: 137.710, Lr: 0.1,	Noise Variance: 0.041,	Signal Variance: 5.101,	Lengthscale: 1.969, Graphbandwidth: 2.622
# Update covariance normalization at epoch:  101
# Iteration: 101, Loss: 241.776, Lr: 0.1,	Noise Variance: 0.041,	Signal Variance: 0.228,	Lengthscale: 1.970, Graphbandwidth: 2.621
# Iteration: 102, Loss: 240.900, Lr: 0.1,	Noise Variance: 0.041,	Signal Variance: 0.231,	Lengthscale: 1.969, Graphbandwidth: 2.616
# Iteration: 103, Loss: 239.286, Lr: 0.1,	Noise Variance: 0.041,	Signal Variance: 0.236,	Lengthscale: 1.967, Graphbandwidth: 2.610
# Iteration: 104, Loss: 237.019, Lr: 0.1,	Noise Variance: 0.041,	Signal Variance: 0.243,	Lengthscale: 1.964, Graphbandwidth: 2.601
# Iteration: 105, Loss: 234.181, Lr: 0.1,	Noise Variance: 0.041,	Signal Variance: 0.253,	Lengthscale: 1.960, Graphbandwidth: 2.590
# Iteration: 106, Loss: 230.847, Lr: 0.1,	Noise Variance: 0.041,	Signal Variance: 0.264,	Lengthscale: 1.955, Graphbandwidth: 2.577
# Iteration: 107, Loss: 227.088, Lr: 0.1,	Noise Variance: 0.041,	Signal Variance: 0.278,	Lengthscale: 1.949, Graphbandwidth: 2.563
# Iteration: 108, Loss: 222.974, Lr: 0.1,	Noise Variance: 0.041,	Signal Variance: 0.294,	Lengthscale: 1.943, Graphbandwidth: 2.548
# Iteration: 109, Loss: 218.569, Lr: 0.1,	Noise Variance: 0.041,	Signal Variance: 0.312,	Lengthscale: 1.936, Graphbandwidth: 2.531
# Iteration: 110, Loss: 213.934, Lr: 0.1,	Noise Variance: 0.041,	Signal Variance: 0.332,	Lengthscale: 1.928, Graphbandwidth: 2.514
# Iteration: 111, Loss: 209.129, Lr: 0.1,	Noise Variance: 0.040,	Signal Variance: 0.355,	Lengthscale: 1.920, Graphbandwidth: 2.495
# Iteration: 112, Loss: 204.208, Lr: 0.1,	Noise Variance: 0.040,	Signal Variance: 0.380,	Lengthscale: 1.911, Graphbandwidth: 2.476
# Iteration: 113, Loss: 199.226, Lr: 0.1,	Noise Variance: 0.040,	Signal Variance: 0.407,	Lengthscale: 1.902, Graphbandwidth: 2.457
# Iteration: 114, Loss: 194.234, Lr: 0.1,	Noise Variance: 0.040,	Signal Variance: 0.436,	Lengthscale: 1.892, Graphbandwidth: 2.437
# Iteration: 115, Loss: 189.279, Lr: 0.1,	Noise Variance: 0.040,	Signal Variance: 0.468,	Lengthscale: 1.882, Graphbandwidth: 2.417
# Iteration: 116, Loss: 184.406, Lr: 0.1,	Noise Variance: 0.040,	Signal Variance: 0.502,	Lengthscale: 1.872, Graphbandwidth: 2.397
# Iteration: 117, Loss: 179.658, Lr: 0.1,	Noise Variance: 0.040,	Signal Variance: 0.538,	Lengthscale: 1.862, Graphbandwidth: 2.377
# Iteration: 118, Loss: 175.074, Lr: 0.1,	Noise Variance: 0.040,	Signal Variance: 0.576,	Lengthscale: 1.851, Graphbandwidth: 2.357
# Iteration: 119, Loss: 170.688, Lr: 0.1,	Noise Variance: 0.040,	Signal Variance: 0.616,	Lengthscale: 1.840, Graphbandwidth: 2.337
# Iteration: 120, Loss: 166.531, Lr: 0.1,	Noise Variance: 0.040,	Signal Variance: 0.658,	Lengthscale: 1.830, Graphbandwidth: 2.317
# Iteration: 121, Loss: 162.630, Lr: 0.1,	Noise Variance: 0.040,	Signal Variance: 0.701,	Lengthscale: 1.819, Graphbandwidth: 2.298
# Iteration: 122, Loss: 159.005, Lr: 0.1,	Noise Variance: 0.040,	Signal Variance: 0.745,	Lengthscale: 1.808, Graphbandwidth: 2.279
# Iteration: 123, Loss: 155.673, Lr: 0.1,	Noise Variance: 0.040,	Signal Variance: 0.791,	Lengthscale: 1.797, Graphbandwidth: 2.261
# Iteration: 124, Loss: 152.645, Lr: 0.1,	Noise Variance: 0.040,	Signal Variance: 0.837,	Lengthscale: 1.787, Graphbandwidth: 2.244
# Iteration: 125, Loss: 149.927, Lr: 0.1,	Noise Variance: 0.040,	Signal Variance: 0.883,	Lengthscale: 1.777, Graphbandwidth: 2.227
# Iteration: 126, Loss: 147.520, Lr: 0.1,	Noise Variance: 0.040,	Signal Variance: 0.930,	Lengthscale: 1.766, Graphbandwidth: 2.210
# Iteration: 127, Loss: 145.419, Lr: 0.1,	Noise Variance: 0.040,	Signal Variance: 0.976,	Lengthscale: 1.756, Graphbandwidth: 2.195
# Iteration: 128, Loss: 143.616, Lr: 0.1,	Noise Variance: 0.039,	Signal Variance: 1.022,	Lengthscale: 1.747, Graphbandwidth: 2.180
# Iteration: 129, Loss: 142.095, Lr: 0.1,	Noise Variance: 0.039,	Signal Variance: 1.066,	Lengthscale: 1.738, Graphbandwidth: 2.166
# Iteration: 130, Loss: 140.841, Lr: 0.1,	Noise Variance: 0.039,	Signal Variance: 1.110,	Lengthscale: 1.729, Graphbandwidth: 2.153
# Iteration: 131, Loss: 139.834, Lr: 0.1,	Noise Variance: 0.039,	Signal Variance: 1.152,	Lengthscale: 1.720, Graphbandwidth: 2.141
# Iteration: 132, Loss: 139.049, Lr: 0.1,	Noise Variance: 0.039,	Signal Variance: 1.193,	Lengthscale: 1.712, Graphbandwidth: 2.129
# Iteration: 133, Loss: 138.463, Lr: 0.1,	Noise Variance: 0.039,	Signal Variance: 1.231,	Lengthscale: 1.705, Graphbandwidth: 2.118
# Iteration: 134, Loss: 138.049, Lr: 0.1,	Noise Variance: 0.039,	Signal Variance: 1.268,	Lengthscale: 1.698, Graphbandwidth: 2.108
# Iteration: 135, Loss: 137.783, Lr: 0.1,	Noise Variance: 0.039,	Signal Variance: 1.302,	Lengthscale: 1.692, Graphbandwidth: 2.099
# Iteration: 136, Loss: 137.637, Lr: 0.1,	Noise Variance: 0.039,	Signal Variance: 1.334,	Lengthscale: 1.686, Graphbandwidth: 2.090
# Iteration: 137, Loss: 137.588, Lr: 0.1,	Noise Variance: 0.039,	Signal Variance: 1.363,	Lengthscale: 1.681, Graphbandwidth: 2.082
# Iteration: 138, Loss: 137.613, Lr: 0.1,	Noise Variance: 0.039,	Signal Variance: 1.390,	Lengthscale: 1.676, Graphbandwidth: 2.075
# Iteration: 139, Loss: 137.689, Lr: 0.1,	Noise Variance: 0.038,	Signal Variance: 1.414,	Lengthscale: 1.672, Graphbandwidth: 2.069
# Iteration: 140, Loss: 137.799, Lr: 0.1,	Noise Variance: 0.038,	Signal Variance: 1.436,	Lengthscale: 1.669, Graphbandwidth: 2.063
# Iteration: 141, Loss: 137.926, Lr: 0.1,	Noise Variance: 0.038,	Signal Variance: 1.455,	Lengthscale: 1.666, Graphbandwidth: 2.058
# Iteration: 142, Loss: 138.057, Lr: 0.1,	Noise Variance: 0.038,	Signal Variance: 1.472,	Lengthscale: 1.664, Graphbandwidth: 2.053
# Iteration: 143, Loss: 138.180, Lr: 0.1,	Noise Variance: 0.038,	Signal Variance: 1.486,	Lengthscale: 1.662, Graphbandwidth: 2.049
# Iteration: 144, Loss: 138.287, Lr: 0.1,	Noise Variance: 0.038,	Signal Variance: 1.498,	Lengthscale: 1.661, Graphbandwidth: 2.046
# Iteration: 145, Loss: 138.373, Lr: 0.1,	Noise Variance: 0.038,	Signal Variance: 1.508,	Lengthscale: 1.661, Graphbandwidth: 2.042
# Iteration: 146, Loss: 138.434, Lr: 0.1,	Noise Variance: 0.038,	Signal Variance: 1.516,	Lengthscale: 1.661, Graphbandwidth: 2.040
# Iteration: 147, Loss: 138.468, Lr: 0.1,	Noise Variance: 0.038,	Signal Variance: 1.522,	Lengthscale: 1.661, Graphbandwidth: 2.038
# Iteration: 148, Loss: 138.476, Lr: 0.1,	Noise Variance: 0.038,	Signal Variance: 1.526,	Lengthscale: 1.662, Graphbandwidth: 2.036
# Iteration: 149, Loss: 138.459, Lr: 0.1,	Noise Variance: 0.038,	Signal Variance: 1.528,	Lengthscale: 1.664, Graphbandwidth: 2.034
# Iteration: 150, Loss: 138.419, Lr: 0.1,	Noise Variance: 0.038,	Signal Variance: 1.529,	Lengthscale: 1.665, Graphbandwidth: 2.033
# Iteration: 151, Loss: 138.360, Lr: 0.1,	Noise Variance: 0.038,	Signal Variance: 1.528,	Lengthscale: 1.667, Graphbandwidth: 2.032
# Iteration: 152, Loss: 138.284, Lr: 0.1,	Noise Variance: 0.038,	Signal Variance: 1.526,	Lengthscale: 1.670, Graphbandwidth: 2.031
# Iteration: 153, Loss: 138.197, Lr: 0.1,	Noise Variance: 0.039,	Signal Variance: 1.523,	Lengthscale: 1.672, Graphbandwidth: 2.030
# Iteration: 154, Loss: 138.101, Lr: 0.1,	Noise Variance: 0.039,	Signal Variance: 1.520,	Lengthscale: 1.675, Graphbandwidth: 2.030
# Iteration: 155, Loss: 138.000, Lr: 0.1,	Noise Variance: 0.039,	Signal Variance: 1.515,	Lengthscale: 1.678, Graphbandwidth: 2.030
# Iteration: 156, Loss: 137.896, Lr: 0.1,	Noise Variance: 0.039,	Signal Variance: 1.510,	Lengthscale: 1.681, Graphbandwidth: 2.029
# Iteration: 157, Loss: 137.794, Lr: 0.1,	Noise Variance: 0.039,	Signal Variance: 1.505,	Lengthscale: 1.684, Graphbandwidth: 2.029
# Iteration: 158, Loss: 137.694, Lr: 0.1,	Noise Variance: 0.039,	Signal Variance: 1.499,	Lengthscale: 1.688, Graphbandwidth: 2.029
# Iteration: 159, Loss: 137.600, Lr: 0.1,	Noise Variance: 0.039,	Signal Variance: 1.493,	Lengthscale: 1.691, Graphbandwidth: 2.029
# Iteration: 160, Loss: 137.511, Lr: 0.1,	Noise Variance: 0.039,	Signal Variance: 1.486,	Lengthscale: 1.694, Graphbandwidth: 2.029
# Iteration: 161, Loss: 137.430, Lr: 0.1,	Noise Variance: 0.039,	Signal Variance: 1.480,	Lengthscale: 1.698, Graphbandwidth: 2.030
# Iteration: 162, Loss: 137.357, Lr: 0.1,	Noise Variance: 0.039,	Signal Variance: 1.474,	Lengthscale: 1.701, Graphbandwidth: 2.030
# Iteration: 163, Loss: 137.291, Lr: 0.1,	Noise Variance: 0.039,	Signal Variance: 1.468,	Lengthscale: 1.704, Graphbandwidth: 2.030
# Iteration: 164, Loss: 137.233, Lr: 0.1,	Noise Variance: 0.039,	Signal Variance: 1.462,	Lengthscale: 1.708, Graphbandwidth: 2.030
# Iteration: 165, Loss: 137.183, Lr: 0.1,	Noise Variance: 0.039,	Signal Variance: 1.456,	Lengthscale: 1.711, Graphbandwidth: 2.030
# Iteration: 166, Loss: 137.140, Lr: 0.1,	Noise Variance: 0.039,	Signal Variance: 1.451,	Lengthscale: 1.714, Graphbandwidth: 2.029
# Iteration: 167, Loss: 137.103, Lr: 0.1,	Noise Variance: 0.039,	Signal Variance: 1.445,	Lengthscale: 1.717, Graphbandwidth: 2.029
# Iteration: 168, Loss: 137.071, Lr: 0.1,	Noise Variance: 0.039,	Signal Variance: 1.441,	Lengthscale: 1.720, Graphbandwidth: 2.029
# Iteration: 169, Loss: 137.045, Lr: 0.1,	Noise Variance: 0.039,	Signal Variance: 1.436,	Lengthscale: 1.722, Graphbandwidth: 2.029
# Iteration: 170, Loss: 137.023, Lr: 0.1,	Noise Variance: 0.040,	Signal Variance: 1.432,	Lengthscale: 1.725, Graphbandwidth: 2.028
# Iteration: 171, Loss: 137.004, Lr: 0.1,	Noise Variance: 0.040,	Signal Variance: 1.429,	Lengthscale: 1.728, Graphbandwidth: 2.028
# Iteration: 172, Loss: 136.987, Lr: 0.1,	Noise Variance: 0.040,	Signal Variance: 1.426,	Lengthscale: 1.730, Graphbandwidth: 2.027
# Iteration: 173, Loss: 136.973, Lr: 0.1,	Noise Variance: 0.040,	Signal Variance: 1.423,	Lengthscale: 1.732, Graphbandwidth: 2.027
# Iteration: 174, Loss: 136.960, Lr: 0.1,	Noise Variance: 0.040,	Signal Variance: 1.421,	Lengthscale: 1.734, Graphbandwidth: 2.026
# Iteration: 175, Loss: 136.947, Lr: 0.1,	Noise Variance: 0.040,	Signal Variance: 1.419,	Lengthscale: 1.736, Graphbandwidth: 2.025
# Iteration: 176, Loss: 136.936, Lr: 0.1,	Noise Variance: 0.040,	Signal Variance: 1.417,	Lengthscale: 1.738, Graphbandwidth: 2.024
# Iteration: 177, Loss: 136.924, Lr: 0.1,	Noise Variance: 0.040,	Signal Variance: 1.416,	Lengthscale: 1.740, Graphbandwidth: 2.023
# Iteration: 178, Loss: 136.912, Lr: 0.1,	Noise Variance: 0.040,	Signal Variance: 1.415,	Lengthscale: 1.742, Graphbandwidth: 2.022
# Iteration: 179, Loss: 136.900, Lr: 0.1,	Noise Variance: 0.040,	Signal Variance: 1.415,	Lengthscale: 1.743, Graphbandwidth: 2.021
# Iteration: 180, Loss: 136.887, Lr: 0.1,	Noise Variance: 0.040,	Signal Variance: 1.415,	Lengthscale: 1.745, Graphbandwidth: 2.020
# Iteration: 181, Loss: 136.873, Lr: 0.1,	Noise Variance: 0.040,	Signal Variance: 1.416,	Lengthscale: 1.746, Graphbandwidth: 2.018
# Iteration: 182, Loss: 136.859, Lr: 0.1,	Noise Variance: 0.040,	Signal Variance: 1.416,	Lengthscale: 1.748, Graphbandwidth: 2.017
# Iteration: 183, Loss: 136.843, Lr: 0.1,	Noise Variance: 0.040,	Signal Variance: 1.417,	Lengthscale: 1.749, Graphbandwidth: 2.016
# Iteration: 184, Loss: 136.828, Lr: 0.1,	Noise Variance: 0.040,	Signal Variance: 1.419,	Lengthscale: 1.750, Graphbandwidth: 2.014
# Iteration: 185, Loss: 136.811, Lr: 0.1,	Noise Variance: 0.039,	Signal Variance: 1.420,	Lengthscale: 1.751, Graphbandwidth: 2.013
# Iteration: 186, Loss: 136.794, Lr: 0.1,	Noise Variance: 0.039,	Signal Variance: 1.422,	Lengthscale: 1.752, Graphbandwidth: 2.011
# Iteration: 187, Loss: 136.776, Lr: 0.1,	Noise Variance: 0.039,	Signal Variance: 1.424,	Lengthscale: 1.753, Graphbandwidth: 2.010
# Iteration: 188, Loss: 136.758, Lr: 0.1,	Noise Variance: 0.039,	Signal Variance: 1.426,	Lengthscale: 1.754, Graphbandwidth: 2.008
# Iteration: 189, Loss: 136.740, Lr: 0.1,	Noise Variance: 0.039,	Signal Variance: 1.428,	Lengthscale: 1.755, Graphbandwidth: 2.006
# Iteration: 190, Loss: 136.722, Lr: 0.1,	Noise Variance: 0.039,	Signal Variance: 1.430,	Lengthscale: 1.756, Graphbandwidth: 2.005
# Iteration: 191, Loss: 136.703, Lr: 0.1,	Noise Variance: 0.039,	Signal Variance: 1.433,	Lengthscale: 1.756, Graphbandwidth: 2.003
# Iteration: 192, Loss: 136.684, Lr: 0.1,	Noise Variance: 0.039,	Signal Variance: 1.435,	Lengthscale: 1.757, Graphbandwidth: 2.001
# Iteration: 193, Loss: 136.665, Lr: 0.1,	Noise Variance: 0.039,	Signal Variance: 1.438,	Lengthscale: 1.758, Graphbandwidth: 2.000
# Iteration: 194, Loss: 136.646, Lr: 0.1,	Noise Variance: 0.039,	Signal Variance: 1.441,	Lengthscale: 1.759, Graphbandwidth: 1.998
# Iteration: 195, Loss: 136.627, Lr: 0.1,	Noise Variance: 0.039,	Signal Variance: 1.443,	Lengthscale: 1.760, Graphbandwidth: 1.996
# Iteration: 196, Loss: 136.608, Lr: 0.1,	Noise Variance: 0.039,	Signal Variance: 1.446,	Lengthscale: 1.761, Graphbandwidth: 1.994
# Iteration: 197, Loss: 136.589, Lr: 0.1,	Noise Variance: 0.039,	Signal Variance: 1.449,	Lengthscale: 1.761, Graphbandwidth: 1.993
# Iteration: 198, Loss: 136.570, Lr: 0.1,	Noise Variance: 0.039,	Signal Variance: 1.451,	Lengthscale: 1.762, Graphbandwidth: 1.991
# Iteration: 199, Loss: 136.551, Lr: 0.1,	Noise Variance: 0.039,	Signal Variance: 1.454,	Lengthscale: 1.763, Graphbandwidth: 1.989
# Iteration: 200, Loss: 136.533, Lr: 0.1,	Noise Variance: 0.039,	Signal Variance: 1.457,	Lengthscale: 1.764, Graphbandwidth: 1.987
# Iteration: 201, Loss: 136.514, Lr: 0.1,	Noise Variance: 0.039,	Signal Variance: 1.459,	Lengthscale: 1.765, Graphbandwidth: 1.986
# Update covariance normalization at epoch:  202
# Iteration: 202, Loss: 145.470, Lr: 0.1,	Noise Variance: 0.039,	Signal Variance: 0.757,	Lengthscale: 1.765, Graphbandwidth: 1.984
# Iteration: 203, Loss: 145.246, Lr: 0.1,	Noise Variance: 0.039,	Signal Variance: 0.762,	Lengthscale: 1.765, Graphbandwidth: 1.982
# Iteration: 204, Loss: 144.886, Lr: 0.1,	Noise Variance: 0.039,	Signal Variance: 0.770,	Lengthscale: 1.764, Graphbandwidth: 1.979
# Iteration: 205, Loss: 144.415, Lr: 0.1,	Noise Variance: 0.039,	Signal Variance: 0.780,	Lengthscale: 1.763, Graphbandwidth: 1.976
# Iteration: 206, Loss: 143.858, Lr: 0.1,	Noise Variance: 0.039,	Signal Variance: 0.793,	Lengthscale: 1.760, Graphbandwidth: 1.972
# Iteration: 207, Loss: 143.239, Lr: 0.1,	Noise Variance: 0.039,	Signal Variance: 0.808,	Lengthscale: 1.757, Graphbandwidth: 1.969
# Iteration: 208, Loss: 142.580, Lr: 0.1,	Noise Variance: 0.038,	Signal Variance: 0.825,	Lengthscale: 1.754, Graphbandwidth: 1.965
# Iteration: 209, Loss: 141.904, Lr: 0.1,	Noise Variance: 0.038,	Signal Variance: 0.843,	Lengthscale: 1.750, Graphbandwidth: 1.960
# Iteration: 210, Loss: 141.230, Lr: 0.1,	Noise Variance: 0.038,	Signal Variance: 0.863,	Lengthscale: 1.746, Graphbandwidth: 1.956
# Iteration: 211, Loss: 140.575, Lr: 0.1,	Noise Variance: 0.038,	Signal Variance: 0.884,	Lengthscale: 1.741, Graphbandwidth: 1.952
# Iteration: 212, Loss: 139.952, Lr: 0.1,	Noise Variance: 0.038,	Signal Variance: 0.906,	Lengthscale: 1.737, Graphbandwidth: 1.947
# Iteration: 213, Loss: 139.373, Lr: 0.1,	Noise Variance: 0.038,	Signal Variance: 0.928,	Lengthscale: 1.732, Graphbandwidth: 1.943
# Iteration: 214, Loss: 138.847, Lr: 0.1,	Noise Variance: 0.038,	Signal Variance: 0.950,	Lengthscale: 1.727, Graphbandwidth: 1.939
# Iteration: 215, Loss: 138.379, Lr: 0.1,	Noise Variance: 0.038,	Signal Variance: 0.973,	Lengthscale: 1.723, Graphbandwidth: 1.934
# Iteration: 216, Loss: 137.972, Lr: 0.1,	Noise Variance: 0.038,	Signal Variance: 0.996,	Lengthscale: 1.718, Graphbandwidth: 1.930
# Iteration: 217, Loss: 137.627, Lr: 0.1,	Noise Variance: 0.037,	Signal Variance: 1.019,	Lengthscale: 1.714, Graphbandwidth: 1.926
# Iteration: 218, Loss: 137.343, Lr: 0.1,	Noise Variance: 0.037,	Signal Variance: 1.040,	Lengthscale: 1.709, Graphbandwidth: 1.922
# Iteration: 219, Loss: 137.117, Lr: 0.1,	Noise Variance: 0.037,	Signal Variance: 1.062,	Lengthscale: 1.705, Graphbandwidth: 1.918
# Iteration: 220, Loss: 136.943, Lr: 0.1,	Noise Variance: 0.037,	Signal Variance: 1.082,	Lengthscale: 1.702, Graphbandwidth: 1.914
# Iteration: 221, Loss: 136.816, Lr: 0.1,	Noise Variance: 0.037,	Signal Variance: 1.102,	Lengthscale: 1.698, Graphbandwidth: 1.911
# Iteration: 222, Loss: 136.729, Lr: 0.1,	Noise Variance: 0.037,	Signal Variance: 1.120,	Lengthscale: 1.695, Graphbandwidth: 1.907
# Iteration: 223, Loss: 136.676, Lr: 0.1,	Noise Variance: 0.037,	Signal Variance: 1.138,	Lengthscale: 1.692, Graphbandwidth: 1.904
# Iteration: 224, Loss: 136.650, Lr: 0.1,	Noise Variance: 0.037,	Signal Variance: 1.154,	Lengthscale: 1.690, Graphbandwidth: 1.901
# Iteration: 225, Loss: 136.643, Lr: 0.1,	Noise Variance: 0.037,	Signal Variance: 1.168,	Lengthscale: 1.688, Graphbandwidth: 1.898
# Iteration: 226, Loss: 136.651, Lr: 0.1,	Noise Variance: 0.036,	Signal Variance: 1.182,	Lengthscale: 1.686, Graphbandwidth: 1.895
# Iteration: 227, Loss: 136.666, Lr: 0.1,	Noise Variance: 0.036,	Signal Variance: 1.194,	Lengthscale: 1.685, Graphbandwidth: 1.893
# Iteration: 228, Loss: 136.685, Lr: 0.1,	Noise Variance: 0.036,	Signal Variance: 1.204,	Lengthscale: 1.684, Graphbandwidth: 1.890
# Iteration: 229, Loss: 136.704, Lr: 0.1,	Noise Variance: 0.036,	Signal Variance: 1.213,	Lengthscale: 1.683, Graphbandwidth: 1.888
# Iteration: 230, Loss: 136.718, Lr: 0.1,	Noise Variance: 0.036,	Signal Variance: 1.221,	Lengthscale: 1.683, Graphbandwidth: 1.886
# Iteration: 231, Loss: 136.728, Lr: 0.1,	Noise Variance: 0.036,	Signal Variance: 1.228,	Lengthscale: 1.683, Graphbandwidth: 1.884
# Iteration: 232, Loss: 136.729, Lr: 0.1,	Noise Variance: 0.036,	Signal Variance: 1.233,	Lengthscale: 1.684, Graphbandwidth: 1.882
# Iteration: 233, Loss: 136.723, Lr: 0.1,	Noise Variance: 0.036,	Signal Variance: 1.237,	Lengthscale: 1.684, Graphbandwidth: 1.881
# Iteration: 234, Loss: 136.709, Lr: 0.1,	Noise Variance: 0.036,	Signal Variance: 1.240,	Lengthscale: 1.685, Graphbandwidth: 1.879
# Iteration: 235, Loss: 136.688, Lr: 0.1,	Noise Variance: 0.036,	Signal Variance: 1.243,	Lengthscale: 1.687, Graphbandwidth: 1.878
# Iteration: 236, Loss: 136.659, Lr: 0.1,	Noise Variance: 0.036,	Signal Variance: 1.244,	Lengthscale: 1.688, Graphbandwidth: 1.876
# Iteration: 237, Loss: 136.625, Lr: 0.1,	Noise Variance: 0.036,	Signal Variance: 1.245,	Lengthscale: 1.690, Graphbandwidth: 1.875
# Iteration: 238, Loss: 136.586, Lr: 0.1,	Noise Variance: 0.036,	Signal Variance: 1.244,	Lengthscale: 1.692, Graphbandwidth: 1.874
# Iteration: 239, Loss: 136.543, Lr: 0.1,	Noise Variance: 0.036,	Signal Variance: 1.244,	Lengthscale: 1.694, Graphbandwidth: 1.872
# Iteration: 240, Loss: 136.499, Lr: 0.1,	Noise Variance: 0.036,	Signal Variance: 1.242,	Lengthscale: 1.697, Graphbandwidth: 1.871
# Iteration: 241, Loss: 136.453, Lr: 0.1,	Noise Variance: 0.036,	Signal Variance: 1.241,	Lengthscale: 1.699, Graphbandwidth: 1.870
# Iteration: 242, Loss: 136.407, Lr: 0.1,	Noise Variance: 0.036,	Signal Variance: 1.239,	Lengthscale: 1.702, Graphbandwidth: 1.869
# Iteration: 243, Loss: 136.362, Lr: 0.1,	Noise Variance: 0.036,	Signal Variance: 1.237,	Lengthscale: 1.704, Graphbandwidth: 1.868
# Iteration: 244, Loss: 136.319, Lr: 0.1,	Noise Variance: 0.036,	Signal Variance: 1.235,	Lengthscale: 1.707, Graphbandwidth: 1.867
# Iteration: 245, Loss: 136.277, Lr: 0.1,	Noise Variance: 0.036,	Signal Variance: 1.232,	Lengthscale: 1.710, Graphbandwidth: 1.866
# Iteration: 246, Loss: 136.238, Lr: 0.1,	Noise Variance: 0.036,	Signal Variance: 1.230,	Lengthscale: 1.712, Graphbandwidth: 1.865
# Iteration: 247, Loss: 136.201, Lr: 0.1,	Noise Variance: 0.036,	Signal Variance: 1.227,	Lengthscale: 1.715, Graphbandwidth: 1.864
# Iteration: 248, Loss: 136.167, Lr: 0.1,	Noise Variance: 0.036,	Signal Variance: 1.225,	Lengthscale: 1.717, Graphbandwidth: 1.863
# Iteration: 249, Loss: 136.135, Lr: 0.1,	Noise Variance: 0.036,	Signal Variance: 1.223,	Lengthscale: 1.720, Graphbandwidth: 1.862
# Iteration: 250, Loss: 136.105, Lr: 0.1,	Noise Variance: 0.036,	Signal Variance: 1.221,	Lengthscale: 1.723, Graphbandwidth: 1.861
# Iteration: 251, Loss: 136.078, Lr: 0.1,	Noise Variance: 0.036,	Signal Variance: 1.220,	Lengthscale: 1.725, Graphbandwidth: 1.860
# Iteration: 252, Loss: 136.052, Lr: 0.1,	Noise Variance: 0.036,	Signal Variance: 1.218,	Lengthscale: 1.727, Graphbandwidth: 1.858
# Iteration: 253, Loss: 136.028, Lr: 0.1,	Noise Variance: 0.036,	Signal Variance: 1.217,	Lengthscale: 1.730, Graphbandwidth: 1.857
# Iteration: 254, Loss: 136.005, Lr: 0.1,	Noise Variance: 0.036,	Signal Variance: 1.216,	Lengthscale: 1.732, Graphbandwidth: 1.856
# Iteration: 255, Loss: 135.982, Lr: 0.1,	Noise Variance: 0.036,	Signal Variance: 1.215,	Lengthscale: 1.734, Graphbandwidth: 1.855
# Iteration: 256, Loss: 135.961, Lr: 0.1,	Noise Variance: 0.036,	Signal Variance: 1.215,	Lengthscale: 1.736, Graphbandwidth: 1.854
# Iteration: 257, Loss: 135.940, Lr: 0.1,	Noise Variance: 0.036,	Signal Variance: 1.215,	Lengthscale: 1.738, Graphbandwidth: 1.852
# Iteration: 258, Loss: 135.919, Lr: 0.1,	Noise Variance: 0.036,	Signal Variance: 1.215,	Lengthscale: 1.740, Graphbandwidth: 1.851
# Iteration: 259, Loss: 135.898, Lr: 0.1,	Noise Variance: 0.036,	Signal Variance: 1.216,	Lengthscale: 1.742, Graphbandwidth: 1.850
# Iteration: 260, Loss: 135.877, Lr: 0.1,	Noise Variance: 0.036,	Signal Variance: 1.217,	Lengthscale: 1.744, Graphbandwidth: 1.848
# Iteration: 261, Loss: 135.855, Lr: 0.1,	Noise Variance: 0.036,	Signal Variance: 1.218,	Lengthscale: 1.746, Graphbandwidth: 1.847
# Iteration: 262, Loss: 135.834, Lr: 0.1,	Noise Variance: 0.036,	Signal Variance: 1.220,	Lengthscale: 1.747, Graphbandwidth: 1.846
# Iteration: 263, Loss: 135.811, Lr: 0.1,	Noise Variance: 0.036,	Signal Variance: 1.221,	Lengthscale: 1.749, Graphbandwidth: 1.844
# Iteration: 264, Loss: 135.789, Lr: 0.1,	Noise Variance: 0.036,	Signal Variance: 1.223,	Lengthscale: 1.750, Graphbandwidth: 1.843
# Iteration: 265, Loss: 135.766, Lr: 0.1,	Noise Variance: 0.036,	Signal Variance: 1.225,	Lengthscale: 1.752, Graphbandwidth: 1.841
# Iteration: 266, Loss: 135.743, Lr: 0.1,	Noise Variance: 0.036,	Signal Variance: 1.228,	Lengthscale: 1.753, Graphbandwidth: 1.840
# Iteration: 267, Loss: 135.719, Lr: 0.1,	Noise Variance: 0.036,	Signal Variance: 1.230,	Lengthscale: 1.755, Graphbandwidth: 1.838
# Iteration: 268, Loss: 135.695, Lr: 0.1,	Noise Variance: 0.036,	Signal Variance: 1.233,	Lengthscale: 1.756, Graphbandwidth: 1.837
# Iteration: 269, Loss: 135.671, Lr: 0.1,	Noise Variance: 0.036,	Signal Variance: 1.236,	Lengthscale: 1.757, Graphbandwidth: 1.835
# Iteration: 270, Loss: 135.646, Lr: 0.1,	Noise Variance: 0.036,	Signal Variance: 1.239,	Lengthscale: 1.759, Graphbandwidth: 1.834
# Iteration: 271, Loss: 135.621, Lr: 0.1,	Noise Variance: 0.036,	Signal Variance: 1.242,	Lengthscale: 1.760, Graphbandwidth: 1.832
# Iteration: 272, Loss: 135.596, Lr: 0.1,	Noise Variance: 0.036,	Signal Variance: 1.245,	Lengthscale: 1.761, Graphbandwidth: 1.831
# Iteration: 273, Loss: 135.571, Lr: 0.1,	Noise Variance: 0.036,	Signal Variance: 1.249,	Lengthscale: 1.762, Graphbandwidth: 1.829
# Iteration: 274, Loss: 135.546, Lr: 0.1,	Noise Variance: 0.036,	Signal Variance: 1.252,	Lengthscale: 1.763, Graphbandwidth: 1.827
# Iteration: 275, Loss: 135.521, Lr: 0.1,	Noise Variance: 0.036,	Signal Variance: 1.255,	Lengthscale: 1.765, Graphbandwidth: 1.826
# Iteration: 276, Loss: 135.495, Lr: 0.1,	Noise Variance: 0.036,	Signal Variance: 1.259,	Lengthscale: 1.766, Graphbandwidth: 1.824
# Iteration: 277, Loss: 135.470, Lr: 0.1,	Noise Variance: 0.036,	Signal Variance: 1.262,	Lengthscale: 1.767, Graphbandwidth: 1.823
# Iteration: 278, Loss: 135.445, Lr: 0.1,	Noise Variance: 0.036,	Signal Variance: 1.266,	Lengthscale: 1.768, Graphbandwidth: 1.821
# Iteration: 279, Loss: 135.419, Lr: 0.1,	Noise Variance: 0.035,	Signal Variance: 1.269,	Lengthscale: 1.770, Graphbandwidth: 1.820
# Iteration: 280, Loss: 135.394, Lr: 0.1,	Noise Variance: 0.035,	Signal Variance: 1.273,	Lengthscale: 1.771, Graphbandwidth: 1.818
# Iteration: 281, Loss: 135.369, Lr: 0.1,	Noise Variance: 0.035,	Signal Variance: 1.276,	Lengthscale: 1.772, Graphbandwidth: 1.817
# Iteration: 282, Loss: 135.343, Lr: 0.1,	Noise Variance: 0.035,	Signal Variance: 1.280,	Lengthscale: 1.773, Graphbandwidth: 1.815
# Iteration: 283, Loss: 135.318, Lr: 0.1,	Noise Variance: 0.035,	Signal Variance: 1.283,	Lengthscale: 1.775, Graphbandwidth: 1.813
# Iteration: 284, Loss: 135.292, Lr: 0.1,	Noise Variance: 0.035,	Signal Variance: 1.286,	Lengthscale: 1.776, Graphbandwidth: 1.812
# Iteration: 285, Loss: 135.267, Lr: 0.1,	Noise Variance: 0.035,	Signal Variance: 1.290,	Lengthscale: 1.777, Graphbandwidth: 1.810
# Iteration: 286, Loss: 135.241, Lr: 0.1,	Noise Variance: 0.035,	Signal Variance: 1.293,	Lengthscale: 1.779, Graphbandwidth: 1.809
# Iteration: 287, Loss: 135.215, Lr: 0.1,	Noise Variance: 0.035,	Signal Variance: 1.296,	Lengthscale: 1.780, Graphbandwidth: 1.807
# Iteration: 288, Loss: 135.189, Lr: 0.1,	Noise Variance: 0.035,	Signal Variance: 1.299,	Lengthscale: 1.781, Graphbandwidth: 1.806
# Iteration: 289, Loss: 135.163, Lr: 0.1,	Noise Variance: 0.035,	Signal Variance: 1.302,	Lengthscale: 1.783, Graphbandwidth: 1.804
# Iteration: 290, Loss: 135.137, Lr: 0.1,	Noise Variance: 0.035,	Signal Variance: 1.306,	Lengthscale: 1.784, Graphbandwidth: 1.803
# Iteration: 291, Loss: 135.111, Lr: 0.1,	Noise Variance: 0.035,	Signal Variance: 1.309,	Lengthscale: 1.786, Graphbandwidth: 1.801
# Iteration: 292, Loss: 135.084, Lr: 0.1,	Noise Variance: 0.035,	Signal Variance: 1.312,	Lengthscale: 1.787, Graphbandwidth: 1.800
# Iteration: 293, Loss: 135.058, Lr: 0.1,	Noise Variance: 0.035,	Signal Variance: 1.315,	Lengthscale: 1.789, Graphbandwidth: 1.798
# Iteration: 294, Loss: 135.031, Lr: 0.1,	Noise Variance: 0.035,	Signal Variance: 1.318,	Lengthscale: 1.790, Graphbandwidth: 1.797
# Iteration: 295, Loss: 135.005, Lr: 0.1,	Noise Variance: 0.035,	Signal Variance: 1.321,	Lengthscale: 1.792, Graphbandwidth: 1.795
# Iteration: 296, Loss: 134.978, Lr: 0.1,	Noise Variance: 0.035,	Signal Variance: 1.323,	Lengthscale: 1.793, Graphbandwidth: 1.794
# Iteration: 297, Loss: 134.951, Lr: 0.1,	Noise Variance: 0.035,	Signal Variance: 1.326,	Lengthscale: 1.795, Graphbandwidth: 1.792
# Iteration: 298, Loss: 134.924, Lr: 0.1,	Noise Variance: 0.035,	Signal Variance: 1.329,	Lengthscale: 1.796, Graphbandwidth: 1.791
# Iteration: 299, Loss: 134.896, Lr: 0.1,	Noise Variance: 0.035,	Signal Variance: 1.332,	Lengthscale: 1.798, Graphbandwidth: 1.789
# Iteration: 300, Loss: 134.869, Lr: 0.1,	Noise Variance: 0.035,	Signal Variance: 1.335,	Lengthscale: 1.799, Graphbandwidth: 1.788
# Iteration: 301, Loss: 134.841, Lr: 0.1,	Noise Variance: 0.035,	Signal Variance: 1.338,	Lengthscale: 1.801, Graphbandwidth: 1.786
# Iteration: 302, Loss: 134.814, Lr: 0.1,	Noise Variance: 0.035,	Signal Variance: 1.341,	Lengthscale: 1.803, Graphbandwidth: 1.785
# Update covariance normalization at epoch:  303
# Iteration: 303, Loss: 139.889, Lr: 0.1,	Noise Variance: 0.034,	Signal Variance: 0.837,	Lengthscale: 1.804, Graphbandwidth: 1.783
# Iteration: 304, Loss: 139.753, Lr: 0.1,	Noise Variance: 0.034,	Signal Variance: 0.843,	Lengthscale: 1.805, Graphbandwidth: 1.782
# Iteration: 305, Loss: 139.526, Lr: 0.1,	Noise Variance: 0.034,	Signal Variance: 0.851,	Lengthscale: 1.805, Graphbandwidth: 1.780
# Iteration: 306, Loss: 139.226, Lr: 0.1,	Noise Variance: 0.034,	Signal Variance: 0.862,	Lengthscale: 1.804, Graphbandwidth: 1.778
# Iteration: 307, Loss: 138.869, Lr: 0.1,	Noise Variance: 0.034,	Signal Variance: 0.875,	Lengthscale: 1.802, Graphbandwidth: 1.776
# Iteration: 308, Loss: 138.475, Lr: 0.1,	Noise Variance: 0.034,	Signal Variance: 0.891,	Lengthscale: 1.800, Graphbandwidth: 1.774
# Iteration: 309, Loss: 138.061, Lr: 0.1,	Noise Variance: 0.034,	Signal Variance: 0.908,	Lengthscale: 1.798, Graphbandwidth: 1.771
# Iteration: 310, Loss: 137.640, Lr: 0.1,	Noise Variance: 0.034,	Signal Variance: 0.926,	Lengthscale: 1.795, Graphbandwidth: 1.769
# Iteration: 311, Loss: 137.229, Lr: 0.1,	Noise Variance: 0.034,	Signal Variance: 0.946,	Lengthscale: 1.791, Graphbandwidth: 1.767
# Iteration: 312, Loss: 136.837, Lr: 0.1,	Noise Variance: 0.034,	Signal Variance: 0.967,	Lengthscale: 1.788, Graphbandwidth: 1.764
# Iteration: 313, Loss: 136.474, Lr: 0.1,	Noise Variance: 0.034,	Signal Variance: 0.988,	Lengthscale: 1.784, Graphbandwidth: 1.762
# Iteration: 314, Loss: 136.146, Lr: 0.1,	Noise Variance: 0.033,	Signal Variance: 1.010,	Lengthscale: 1.781, Graphbandwidth: 1.760
# Iteration: 315, Loss: 135.858, Lr: 0.1,	Noise Variance: 0.033,	Signal Variance: 1.031,	Lengthscale: 1.777, Graphbandwidth: 1.757
# Iteration: 316, Loss: 135.612, Lr: 0.1,	Noise Variance: 0.033,	Signal Variance: 1.053,	Lengthscale: 1.774, Graphbandwidth: 1.755
# Iteration: 317, Loss: 135.408, Lr: 0.1,	Noise Variance: 0.033,	Signal Variance: 1.074,	Lengthscale: 1.770, Graphbandwidth: 1.753
# Iteration: 318, Loss: 135.244, Lr: 0.1,	Noise Variance: 0.033,	Signal Variance: 1.095,	Lengthscale: 1.767, Graphbandwidth: 1.750
# Iteration: 319, Loss: 135.118, Lr: 0.1,	Noise Variance: 0.033,	Signal Variance: 1.116,	Lengthscale: 1.764, Graphbandwidth: 1.748
# Iteration: 320, Loss: 135.024, Lr: 0.1,	Noise Variance: 0.033,	Signal Variance: 1.135,	Lengthscale: 1.762, Graphbandwidth: 1.746
# Iteration: 321, Loss: 134.959, Lr: 0.1,	Noise Variance: 0.033,	Signal Variance: 1.153,	Lengthscale: 1.759, Graphbandwidth: 1.744
# Iteration: 322, Loss: 134.916, Lr: 0.1,	Noise Variance: 0.033,	Signal Variance: 1.170,	Lengthscale: 1.757, Graphbandwidth: 1.742
# Iteration: 323, Loss: 134.892, Lr: 0.1,	Noise Variance: 0.032,	Signal Variance: 1.186,	Lengthscale: 1.756, Graphbandwidth: 1.740
# Iteration: 324, Loss: 134.880, Lr: 0.1,	Noise Variance: 0.032,	Signal Variance: 1.201,	Lengthscale: 1.754, Graphbandwidth: 1.739
# Iteration: 325, Loss: 134.877, Lr: 0.1,	Noise Variance: 0.032,	Signal Variance: 1.214,	Lengthscale: 1.753, Graphbandwidth: 1.737
# Iteration: 326, Loss: 134.877, Lr: 0.1,	Noise Variance: 0.032,	Signal Variance: 1.226,	Lengthscale: 1.753, Graphbandwidth: 1.735
# Iteration: 327, Loss: 134.877, Lr: 0.1,	Noise Variance: 0.032,	Signal Variance: 1.237,	Lengthscale: 1.753, Graphbandwidth: 1.734
# Iteration: 328, Loss: 134.876, Lr: 0.1,	Noise Variance: 0.032,	Signal Variance: 1.246,	Lengthscale: 1.753, Graphbandwidth: 1.732
# Iteration: 329, Loss: 134.870, Lr: 0.1,	Noise Variance: 0.032,	Signal Variance: 1.254,	Lengthscale: 1.754, Graphbandwidth: 1.731
# Iteration: 330, Loss: 134.858, Lr: 0.1,	Noise Variance: 0.032,	Signal Variance: 1.261,	Lengthscale: 1.754, Graphbandwidth: 1.729
# Iteration: 331, Loss: 134.840, Lr: 0.1,	Noise Variance: 0.032,	Signal Variance: 1.267,	Lengthscale: 1.756, Graphbandwidth: 1.728
# Iteration: 332, Loss: 134.816, Lr: 0.1,	Noise Variance: 0.032,	Signal Variance: 1.271,	Lengthscale: 1.757, Graphbandwidth: 1.726
# Iteration: 333, Loss: 134.786, Lr: 0.1,	Noise Variance: 0.032,	Signal Variance: 1.275,	Lengthscale: 1.759, Graphbandwidth: 1.725
# Iteration: 334, Loss: 134.750, Lr: 0.1,	Noise Variance: 0.032,	Signal Variance: 1.278,	Lengthscale: 1.761, Graphbandwidth: 1.724
# Iteration: 335, Loss: 134.709, Lr: 0.1,	Noise Variance: 0.032,	Signal Variance: 1.279,	Lengthscale: 1.763, Graphbandwidth: 1.723
# Iteration: 336, Loss: 134.666, Lr: 0.1,	Noise Variance: 0.032,	Signal Variance: 1.281,	Lengthscale: 1.766, Graphbandwidth: 1.721
# Iteration: 337, Loss: 134.619, Lr: 0.1,	Noise Variance: 0.032,	Signal Variance: 1.282,	Lengthscale: 1.768, Graphbandwidth: 1.720
# Iteration: 338, Loss: 134.571, Lr: 0.1,	Noise Variance: 0.032,	Signal Variance: 1.282,	Lengthscale: 1.771, Graphbandwidth: 1.719
# Iteration: 339, Loss: 134.523, Lr: 0.1,	Noise Variance: 0.032,	Signal Variance: 1.282,	Lengthscale: 1.774, Graphbandwidth: 1.718
# Iteration: 340, Loss: 134.475, Lr: 0.1,	Noise Variance: 0.032,	Signal Variance: 1.281,	Lengthscale: 1.777, Graphbandwidth: 1.717
# Iteration: 341, Loss: 134.428, Lr: 0.1,	Noise Variance: 0.032,	Signal Variance: 1.281,	Lengthscale: 1.780, Graphbandwidth: 1.716
# Iteration: 342, Loss: 134.382, Lr: 0.1,	Noise Variance: 0.032,	Signal Variance: 1.280,	Lengthscale: 1.783, Graphbandwidth: 1.715
# Iteration: 343, Loss: 134.338, Lr: 0.1,	Noise Variance: 0.032,	Signal Variance: 1.279,	Lengthscale: 1.786, Graphbandwidth: 1.714
# Iteration: 344, Loss: 134.296, Lr: 0.1,	Noise Variance: 0.032,	Signal Variance: 1.278,	Lengthscale: 1.789, Graphbandwidth: 1.712
# Iteration: 345, Loss: 134.256, Lr: 0.1,	Noise Variance: 0.032,	Signal Variance: 1.278,	Lengthscale: 1.792, Graphbandwidth: 1.711
# Iteration: 346, Loss: 134.219, Lr: 0.1,	Noise Variance: 0.032,	Signal Variance: 1.277,	Lengthscale: 1.795, Graphbandwidth: 1.710
# Iteration: 347, Loss: 134.183, Lr: 0.1,	Noise Variance: 0.032,	Signal Variance: 1.277,	Lengthscale: 1.798, Graphbandwidth: 1.709
# Iteration: 348, Loss: 134.149, Lr: 0.1,	Noise Variance: 0.032,	Signal Variance: 1.277,	Lengthscale: 1.801, Graphbandwidth: 1.708
# Iteration: 349, Loss: 134.116, Lr: 0.1,	Noise Variance: 0.032,	Signal Variance: 1.277,	Lengthscale: 1.803, Graphbandwidth: 1.707
# Iteration: 350, Loss: 134.084, Lr: 0.1,	Noise Variance: 0.032,	Signal Variance: 1.277,	Lengthscale: 1.806, Graphbandwidth: 1.706
# Iteration: 351, Loss: 134.054, Lr: 0.1,	Noise Variance: 0.032,	Signal Variance: 1.278,	Lengthscale: 1.809, Graphbandwidth: 1.705
# Iteration: 352, Loss: 134.024, Lr: 0.1,	Noise Variance: 0.032,	Signal Variance: 1.279,	Lengthscale: 1.811, Graphbandwidth: 1.703
# Iteration: 353, Loss: 133.994, Lr: 0.1,	Noise Variance: 0.031,	Signal Variance: 1.281,	Lengthscale: 1.814, Graphbandwidth: 1.702
# Iteration: 354, Loss: 133.965, Lr: 0.1,	Noise Variance: 0.031,	Signal Variance: 1.282,	Lengthscale: 1.816, Graphbandwidth: 1.701
# Iteration: 355, Loss: 133.936, Lr: 0.1,	Noise Variance: 0.031,	Signal Variance: 1.284,	Lengthscale: 1.819, Graphbandwidth: 1.700
# Iteration: 356, Loss: 133.907, Lr: 0.1,	Noise Variance: 0.031,	Signal Variance: 1.287,	Lengthscale: 1.821, Graphbandwidth: 1.699
# Iteration: 357, Loss: 133.877, Lr: 0.1,	Noise Variance: 0.031,	Signal Variance: 1.290,	Lengthscale: 1.823, Graphbandwidth: 1.698
# Iteration: 358, Loss: 133.848, Lr: 0.1,	Noise Variance: 0.031,	Signal Variance: 1.293,	Lengthscale: 1.825, Graphbandwidth: 1.696
# Iteration: 359, Loss: 133.818, Lr: 0.1,	Noise Variance: 0.031,	Signal Variance: 1.296,	Lengthscale: 1.827, Graphbandwidth: 1.695
# Iteration: 360, Loss: 133.787, Lr: 0.1,	Noise Variance: 0.031,	Signal Variance: 1.299,	Lengthscale: 1.829, Graphbandwidth: 1.694
# Iteration: 361, Loss: 133.756, Lr: 0.1,	Noise Variance: 0.031,	Signal Variance: 1.303,	Lengthscale: 1.831, Graphbandwidth: 1.693
# Iteration: 362, Loss: 133.725, Lr: 0.1,	Noise Variance: 0.031,	Signal Variance: 1.307,	Lengthscale: 1.833, Graphbandwidth: 1.692
# Iteration: 363, Loss: 133.694, Lr: 0.1,	Noise Variance: 0.031,	Signal Variance: 1.311,	Lengthscale: 1.835, Graphbandwidth: 1.690
# Iteration: 364, Loss: 133.662, Lr: 0.1,	Noise Variance: 0.031,	Signal Variance: 1.316,	Lengthscale: 1.836, Graphbandwidth: 1.689
# Iteration: 365, Loss: 133.630, Lr: 0.1,	Noise Variance: 0.031,	Signal Variance: 1.321,	Lengthscale: 1.838, Graphbandwidth: 1.688
# Iteration: 366, Loss: 133.598, Lr: 0.1,	Noise Variance: 0.031,	Signal Variance: 1.325,	Lengthscale: 1.840, Graphbandwidth: 1.687
# Iteration: 367, Loss: 133.565, Lr: 0.1,	Noise Variance: 0.031,	Signal Variance: 1.330,	Lengthscale: 1.841, Graphbandwidth: 1.685
# Iteration: 368, Loss: 133.533, Lr: 0.1,	Noise Variance: 0.031,	Signal Variance: 1.335,	Lengthscale: 1.843, Graphbandwidth: 1.684
# Iteration: 369, Loss: 133.500, Lr: 0.1,	Noise Variance: 0.031,	Signal Variance: 1.340,	Lengthscale: 1.845, Graphbandwidth: 1.683
# ...
# Iteration: 378, Loss: 133.206, Lr: 0.1,	Noise Variance: 0.030,	Signal Variance: 1.388,	Lengthscale: 1.859, Graphbandwidth: 1.672
# Iteration: 379, Loss: 133.173, Lr: 0.1,	Noise Variance: 0.030,	Signal Variance: 1.393,	Lengthscale: 1.861, Graphbandwidth: 1.671
# Iteration: 380, Loss: 133.140, Lr: 0.1,	Noise Variance: 0.030,	Signal Variance: 1.398,	Lengthscale: 1.863, Graphbandwidth: 1.670
# Iteration: 381, Loss: 133.107, Lr: 0.1,	Noise Variance: 0.030,	Signal Variance: 1.403,	Lengthscale: 1.864, Graphbandwidth: 1.669
# Iteration: 382, Loss: 133.074, Lr: 0.1,	Noise Variance: 0.030,	Signal Variance: 1.408,	Lengthscale: 1.866, Graphbandwidth: 1.667
# Iteration: 383, Loss: 133.041, Lr: 0.1,	Noise Variance: 0.030,	Signal Variance: 1.413,	Lengthscale: 1.868, Graphbandwidth: 1.666
# Iteration: 384, Loss: 133.008, Lr: 0.1,	Noise Variance: 0.030,	Signal Variance: 1.418,	Lengthscale: 1.870, Graphbandwidth: 1.665
# Iteration: 385, Loss: 132.975, Lr: 0.1,	Noise Variance: 0.030,	Signal Variance: 1.423,	Lengthscale: 1.872, Graphbandwidth: 1.664
# Iteration: 386, Loss: 132.942, Lr: 0.1,	Noise Variance: 0.030,	Signal Variance: 1.428,	Lengthscale: 1.873, Graphbandwidth: 1.663
# Iteration: 387, Loss: 132.908, Lr: 0.1,	Noise Variance: 0.030,	Signal Variance: 1.433,	Lengthscale: 1.875, Graphbandwidth: 1.662
# Iteration: 388, Loss: 132.875, Lr: 0.1,	Noise Variance: 0.030,	Signal Variance: 1.438,	Lengthscale: 1.877, Graphbandwidth: 1.661
# Iteration: 389, Loss: 132.842, Lr: 0.1,	Noise Variance: 0.029,	Signal Variance: 1.443,	Lengthscale: 1.879, Graphbandwidth: 1.659
# Iteration: 390, Loss: 132.808, Lr: 0.1,	Noise Variance: 0.029,	Signal Variance: 1.448,	Lengthscale: 1.881, Graphbandwidth: 1.658
# Iteration: 391, Loss: 132.774, Lr: 0.1,	Noise Variance: 0.029,	Signal Variance: 1.452,	Lengthscale: 1.883, Graphbandwidth: 1.657
# Iteration: 392, Loss: 132.740, Lr: 0.1,	Noise Variance: 0.029,	Signal Variance: 1.457,	Lengthscale: 1.885, Graphbandwidth: 1.656
# Iteration: 393, Loss: 132.707, Lr: 0.1,	Noise Variance: 0.029,	Signal Variance: 1.462,	Lengthscale: 1.887, Graphbandwidth: 1.655
# Iteration: 394, Loss: 132.673, Lr: 0.1,	Noise Variance: 0.029,	Signal Variance: 1.467,	Lengthscale: 1.889, Graphbandwidth: 1.654
# Iteration: 395, Loss: 132.639, Lr: 0.1,	Noise Variance: 0.029,	Signal Variance: 1.471,	Lengthscale: 1.891, Graphbandwidth: 1.653
# Iteration: 396, Loss: 132.604, Lr: 0.1,	Noise Variance: 0.029,	Signal Variance: 1.476,	Lengthscale: 1.893, Graphbandwidth: 1.652
# Iteration: 397, Loss: 132.570, Lr: 0.1,	Noise Variance: 0.029,	Signal Variance: 1.481,	Lengthscale: 1.895, Graphbandwidth: 1.651
# Iteration: 398, Loss: 132.536, Lr: 0.1,	Noise Variance: 0.029,	Signal Variance: 1.486,	Lengthscale: 1.897, Graphbandwidth: 1.649
# Iteration: 399, Loss: 132.502, Lr: 0.1,	Noise Variance: 0.029,	Signal Variance: 1.490,	Lengthscale: 1.899, Graphbandwidth: 1.648
# Iteration: 400, Loss: 132.467, Lr: 0.1,	Noise Variance: 0.029,	Signal Variance: 1.495,	Lengthscale: 1.901, Graphbandwidth: 1.647
# Iteration: 401, Loss: 132.433, Lr: 0.1,	Noise Variance: 0.029,	Signal Variance: 1.500,	Lengthscale: 1.903, Graphbandwidth: 1.646
# Iteration: 402, Loss: 132.398, Lr: 0.1,	Noise Variance: 0.029,	Signal Variance: 1.505,	Lengthscale: 1.906, Graphbandwidth: 1.645
# Iteration: 403, Loss: 132.363, Lr: 0.1,	Noise Variance: 0.029,	Signal Variance: 1.510,	Lengthscale: 1.908, Graphbandwidth: 1.644
# Update covariance normalization at epoch:  404
# Iteration: 404, Loss: 142.803, Lr: 0.1,	Noise Variance: 0.029,	Signal Variance: 0.756,	Lengthscale: 1.910, Graphbandwidth: 1.643
# Iteration: 405, Loss: 142.522, Lr: 0.1,	Noise Variance: 0.029,	Signal Variance: 0.764,	Lengthscale: 1.910, Graphbandwidth: 1.642
# Iteration: 406, Loss: 142.046, Lr: 0.1,	Noise Variance: 0.028,	Signal Variance: 0.777,	Lengthscale: 1.910, Graphbandwidth: 1.641
# Iteration: 407, Loss: 141.412, Lr: 0.1,	Noise Variance: 0.028,	Signal Variance: 0.794,	Lengthscale: 1.908, Graphbandwidth: 1.639
# Iteration: 408, Loss: 140.662, Lr: 0.1,	Noise Variance: 0.028,	Signal Variance: 0.814,	Lengthscale: 1.905, Graphbandwidth: 1.638
# Iteration: 409, Loss: 139.834, Lr: 0.1,	Noise Variance: 0.028,	Signal Variance: 0.838,	Lengthscale: 1.901, Graphbandwidth: 1.637
# Iteration: 410, Loss: 138.965, Lr: 0.1,	Noise Variance: 0.028,	Signal Variance: 0.865,	Lengthscale: 1.896, Graphbandwidth: 1.635
# Iteration: 411, Loss: 138.090, Lr: 0.1,	Noise Variance: 0.028,	Signal Variance: 0.894,	Lengthscale: 1.891, Graphbandwidth: 1.634
# Iteration: 412, Loss: 137.239, Lr: 0.1,	Noise Variance: 0.028,	Signal Variance: 0.926,	Lengthscale: 1.886, Graphbandwidth: 1.632
# Iteration: 413, Loss: 136.436, Lr: 0.1,	Noise Variance: 0.028,	Signal Variance: 0.959,	Lengthscale: 1.880, Graphbandwidth: 1.631
# Iteration: 414, Loss: 135.701, Lr: 0.1,	Noise Variance: 0.028,	Signal Variance: 0.993,	Lengthscale: 1.874, Graphbandwidth: 1.629
# Iteration: 415, Loss: 135.049, Lr: 0.1,	Noise Variance: 0.027,	Signal Variance: 1.028,	Lengthscale: 1.868, Graphbandwidth: 1.628
# Iteration: 416, Loss: 134.487, Lr: 0.1,	Noise Variance: 0.027,	Signal Variance: 1.063,	Lengthscale: 1.862, Graphbandwidth: 1.626
# Iteration: 417, Loss: 134.019, Lr: 0.1,	Noise Variance: 0.027,	Signal Variance: 1.098,	Lengthscale: 1.856, Graphbandwidth: 1.625
# Iteration: 418, Loss: 133.645, Lr: 0.1,	Noise Variance: 0.027,	Signal Variance: 1.133,	Lengthscale: 1.850, Graphbandwidth: 1.623
# Iteration: 419, Loss: 133.360, Lr: 0.1,	Noise Variance: 0.027,	Signal Variance: 1.166,	Lengthscale: 1.845, Graphbandwidth: 1.622
# Iteration: 420, Loss: 133.155, Lr: 0.1,	Noise Variance: 0.027,	Signal Variance: 1.199,	Lengthscale: 1.840, Graphbandwidth: 1.621
# Iteration: 421, Loss: 133.020, Lr: 0.1,	Noise Variance: 0.027,	Signal Variance: 1.230,	Lengthscale: 1.836, Graphbandwidth: 1.619
# Iteration: 422, Loss: 132.943, Lr: 0.1,	Noise Variance: 0.027,	Signal Variance: 1.259,	Lengthscale: 1.832, Graphbandwidth: 1.618
# Iteration: 423, Loss: 132.911, Lr: 0.1,	Noise Variance: 0.027,	Signal Variance: 1.286,	Lengthscale: 1.828, Graphbandwidth: 1.617
# Iteration: 424, Loss: 132.912, Lr: 0.1,	Noise Variance: 0.026,	Signal Variance: 1.311,	Lengthscale: 1.826, Graphbandwidth: 1.616
# Iteration: 425, Loss: 132.934, Lr: 0.1,	Noise Variance: 0.026,	Signal Variance: 1.334,	Lengthscale: 1.823, Graphbandwidth: 1.615
# Iteration: 426, Loss: 132.967, Lr: 0.1,	Noise Variance: 0.026,	Signal Variance: 1.355,	Lengthscale: 1.822, Graphbandwidth: 1.613
# Iteration: 427, Loss: 133.002, Lr: 0.1,	Noise Variance: 0.026,	Signal Variance: 1.373,	Lengthscale: 1.821, Graphbandwidth: 1.612
# Iteration: 428, Loss: 133.031, Lr: 0.1,	Noise Variance: 0.026,	Signal Variance: 1.388,	Lengthscale: 1.821, Graphbandwidth: 1.611
# Iteration: 429, Loss: 133.049, Lr: 0.1,	Noise Variance: 0.026,	Signal Variance: 1.402,	Lengthscale: 1.821, Graphbandwidth: 1.610
# Iteration: 430, Loss: 133.054, Lr: 0.1,	Noise Variance: 0.026,	Signal Variance: 1.413,	Lengthscale: 1.822, Graphbandwidth: 1.610
# Iteration: 431, Loss: 133.043, Lr: 0.1,	Noise Variance: 0.026,	Signal Variance: 1.423,	Lengthscale: 1.824, Graphbandwidth: 1.609
# Iteration: 432, Loss: 133.016, Lr: 0.1,	Noise Variance: 0.026,	Signal Variance: 1.430,	Lengthscale: 1.826, Graphbandwidth: 1.608
# Iteration: 433, Loss: 132.974, Lr: 0.1,	Noise Variance: 0.026,	Signal Variance: 1.436,	Lengthscale: 1.828, Graphbandwidth: 1.607
# Iteration: 434, Loss: 132.919, Lr: 0.1,	Noise Variance: 0.026,	Signal Variance: 1.440,	Lengthscale: 1.831, Graphbandwidth: 1.606
# Iteration: 435, Loss: 132.854, Lr: 0.1,	Noise Variance: 0.026,	Signal Variance: 1.442,	Lengthscale: 1.834, Graphbandwidth: 1.605
# Iteration: 436, Loss: 132.780, Lr: 0.1,	Noise Variance: 0.026,	Signal Variance: 1.444,	Lengthscale: 1.838, Graphbandwidth: 1.604
# Iteration: 437, Loss: 132.702, Lr: 0.1,	Noise Variance: 0.026,	Signal Variance: 1.444,	Lengthscale: 1.842, Graphbandwidth: 1.604
# Iteration: 438, Loss: 132.621, Lr: 0.1,	Noise Variance: 0.026,	Signal Variance: 1.444,	Lengthscale: 1.846, Graphbandwidth: 1.603
# Iteration: 439, Loss: 132.540, Lr: 0.1,	Noise Variance: 0.026,	Signal Variance: 1.443,	Lengthscale: 1.850, Graphbandwidth: 1.602
# Iteration: 440, Loss: 132.460, Lr: 0.1,	Noise Variance: 0.026,	Signal Variance: 1.442,	Lengthscale: 1.854, Graphbandwidth: 1.602
# Iteration: 441, Loss: 132.384, Lr: 0.1,	Noise Variance: 0.026,	Signal Variance: 1.440,	Lengthscale: 1.859, Graphbandwidth: 1.601
# Iteration: 442, Loss: 132.312, Lr: 0.1,	Noise Variance: 0.026,	Signal Variance: 1.438,	Lengthscale: 1.863, Graphbandwidth: 1.600
# Iteration: 443, Loss: 132.246, Lr: 0.1,	Noise Variance: 0.026,	Signal Variance: 1.436,	Lengthscale: 1.868, Graphbandwidth: 1.599
# Iteration: 444, Loss: 132.185, Lr: 0.1,	Noise Variance: 0.026,	Signal Variance: 1.434,	Lengthscale: 1.872, Graphbandwidth: 1.599
# Iteration: 445, Loss: 132.129, Lr: 0.1,	Noise Variance: 0.026,	Signal Variance: 1.433,	Lengthscale: 1.876, Graphbandwidth: 1.598
# Iteration: 446, Loss: 132.078, Lr: 0.1,	Noise Variance: 0.026,	Signal Variance: 1.431,	Lengthscale: 1.881, Graphbandwidth: 1.597
# Iteration: 447, Loss: 132.032, Lr: 0.1,	Noise Variance: 0.026,	Signal Variance: 1.431,	Lengthscale: 1.885, Graphbandwidth: 1.596
# Iteration: 448, Loss: 131.990, Lr: 0.1,	Noise Variance: 0.026,	Signal Variance: 1.430,	Lengthscale: 1.889, Graphbandwidth: 1.596
# Iteration: 449, Loss: 131.951, Lr: 0.1,	Noise Variance: 0.026,	Signal Variance: 1.430,	Lengthscale: 1.893, Graphbandwidth: 1.595
# Iteration: 450, Loss: 131.915, Lr: 0.1,	Noise Variance: 0.025,	Signal Variance: 1.430,	Lengthscale: 1.897, Graphbandwidth: 1.594
# Iteration: 451, Loss: 131.880, Lr: 0.1,	Noise Variance: 0.025,	Signal Variance: 1.431,	Lengthscale: 1.900, Graphbandwidth: 1.594
# Iteration: 452, Loss: 131.847, Lr: 0.1,	Noise Variance: 0.025,	Signal Variance: 1.433,	Lengthscale: 1.904, Graphbandwidth: 1.593
# Iteration: 453, Loss: 131.815, Lr: 0.1,	Noise Variance: 0.025,	Signal Variance: 1.435,	Lengthscale: 1.907, Graphbandwidth: 1.592
# Iteration: 454, Loss: 131.783, Lr: 0.1,	Noise Variance: 0.025,	Signal Variance: 1.438,	Lengthscale: 1.910, Graphbandwidth: 1.591
# Iteration: 455, Loss: 131.751, Lr: 0.1,	Noise Variance: 0.025,	Signal Variance: 1.441,	Lengthscale: 1.913, Graphbandwidth: 1.591
# Iteration: 456, Loss: 131.718, Lr: 0.1,	Noise Variance: 0.025,	Signal Variance: 1.445,	Lengthscale: 1.916, Graphbandwidth: 1.590
# Iteration: 457, Loss: 131.685, Lr: 0.1,	Noise Variance: 0.025,	Signal Variance: 1.449,	Lengthscale: 1.919, Graphbandwidth: 1.589
# Iteration: 458, Loss: 131.651, Lr: 0.1,	Noise Variance: 0.025,	Signal Variance: 1.454,	Lengthscale: 1.921, Graphbandwidth: 1.588
# Iteration: 459, Loss: 131.616, Lr: 0.1,	Noise Variance: 0.025,	Signal Variance: 1.460,	Lengthscale: 1.924, Graphbandwidth: 1.588
# Iteration: 460, Loss: 131.581, Lr: 0.1,	Noise Variance: 0.025,	Signal Variance: 1.465,	Lengthscale: 1.926, Graphbandwidth: 1.587
# Iteration: 461, Loss: 131.544, Lr: 0.1,	Noise Variance: 0.025,	Signal Variance: 1.471,	Lengthscale: 1.928, Graphbandwidth: 1.586
# Iteration: 462, Loss: 131.508, Lr: 0.1,	Noise Variance: 0.025,	Signal Variance: 1.478,	Lengthscale: 1.931, Graphbandwidth: 1.585
# Iteration: 463, Loss: 131.470, Lr: 0.1,	Noise Variance: 0.025,	Signal Variance: 1.485,	Lengthscale: 1.933, Graphbandwidth: 1.584
# Iteration: 464, Loss: 131.432, Lr: 0.1,	Noise Variance: 0.025,	Signal Variance: 1.492,	Lengthscale: 1.935, Graphbandwidth: 1.584
# Iteration: 465, Loss: 131.394, Lr: 0.1,	Noise Variance: 0.025,	Signal Variance: 1.499,	Lengthscale: 1.937, Graphbandwidth: 1.583
# Iteration: 466, Loss: 131.356, Lr: 0.1,	Noise Variance: 0.025,	Signal Variance: 1.507,	Lengthscale: 1.938, Graphbandwidth: 1.582
# Iteration: 467, Loss: 131.317, Lr: 0.1,	Noise Variance: 0.025,	Signal Variance: 1.515,	Lengthscale: 1.940, Graphbandwidth: 1.581
# Iteration: 468, Loss: 131.279, Lr: 0.1,	Noise Variance: 0.024,	Signal Variance: 1.522,	Lengthscale: 1.942, Graphbandwidth: 1.581
# Iteration: 469, Loss: 131.241, Lr: 0.1,	Noise Variance: 0.024,	Signal Variance: 1.530,	Lengthscale: 1.944, Graphbandwidth: 1.580
# Iteration: 470, Loss: 131.202, Lr: 0.1,	Noise Variance: 0.024,	Signal Variance: 1.539,	Lengthscale: 1.946, Graphbandwidth: 1.579
# Iteration: 471, Loss: 131.164, Lr: 0.1,	Noise Variance: 0.024,	Signal Variance: 1.547,	Lengthscale: 1.948, Graphbandwidth: 1.578
# Iteration: 472, Loss: 131.126, Lr: 0.1,	Noise Variance: 0.024,	Signal Variance: 1.555,	Lengthscale: 1.949, Graphbandwidth: 1.578
# Iteration: 473, Loss: 131.088, Lr: 0.1,	Noise Variance: 0.024,	Signal Variance: 1.563,	Lengthscale: 1.951, Graphbandwidth: 1.577
# Iteration: 474, Loss: 131.051, Lr: 0.1,	Noise Variance: 0.024,	Signal Variance: 1.571,	Lengthscale: 1.953, Graphbandwidth: 1.576
# Iteration: 475, Loss: 131.013, Lr: 0.1,	Noise Variance: 0.024,	Signal Variance: 1.579,	Lengthscale: 1.955, Graphbandwidth: 1.575
# Iteration: 476, Loss: 130.976, Lr: 0.1,	Noise Variance: 0.024,	Signal Variance: 1.587,	Lengthscale: 1.957, Graphbandwidth: 1.575
# Iteration: 477, Loss: 130.939, Lr: 0.1,	Noise Variance: 0.024,	Signal Variance: 1.595,	Lengthscale: 1.959, Graphbandwidth: 1.574
# Iteration: 478, Loss: 130.901, Lr: 0.1,	Noise Variance: 0.024,	Signal Variance: 1.603,	Lengthscale: 1.961, Graphbandwidth: 1.573
# Iteration: 479, Loss: 130.864, Lr: 0.1,	Noise Variance: 0.024,	Signal Variance: 1.611,	Lengthscale: 1.963, Graphbandwidth: 1.572
# Iteration: 480, Loss: 130.827, Lr: 0.1,	Noise Variance: 0.024,	Signal Variance: 1.618,	Lengthscale: 1.965, Graphbandwidth: 1.572
# Iteration: 481, Loss: 130.790, Lr: 0.1,	Noise Variance: 0.024,	Signal Variance: 1.626,	Lengthscale: 1.967, Graphbandwidth: 1.571
# Iteration: 482, Loss: 130.753, Lr: 0.1,	Noise Variance: 0.024,	Signal Variance: 1.633,	Lengthscale: 1.969, Graphbandwidth: 1.570
# Iteration: 483, Loss: 130.716, Lr: 0.1,	Noise Variance: 0.023,	Signal Variance: 1.641,	Lengthscale: 1.971, Graphbandwidth: 1.570
# Iteration: 484, Loss: 130.679, Lr: 0.1,	Noise Variance: 0.023,	Signal Variance: 1.648,	Lengthscale: 1.973, Graphbandwidth: 1.569
# Iteration: 485, Loss: 130.641, Lr: 0.1,	Noise Variance: 0.023,	Signal Variance: 1.656,	Lengthscale: 1.976, Graphbandwidth: 1.568
# Iteration: 486, Loss: 130.604, Lr: 0.1,	Noise Variance: 0.023,	Signal Variance: 1.663,	Lengthscale: 1.978, Graphbandwidth: 1.567
# Iteration: 487, Loss: 130.567, Lr: 0.1,	Noise Variance: 0.023,	Signal Variance: 1.670,	Lengthscale: 1.980, Graphbandwidth: 1.567
# Iteration: 488, Loss: 130.529, Lr: 0.1,	Noise Variance: 0.023,	Signal Variance: 1.677,	Lengthscale: 1.982, Graphbandwidth: 1.566
# Iteration: 489, Loss: 130.491, Lr: 0.1,	Noise Variance: 0.023,	Signal Variance: 1.684,	Lengthscale: 1.985, Graphbandwidth: 1.565
# Iteration: 490, Loss: 130.454, Lr: 0.1,	Noise Variance: 0.023,	Signal Variance: 1.691,	Lengthscale: 1.987, Graphbandwidth: 1.565
# Iteration: 491, Loss: 130.416, Lr: 0.1,	Noise Variance: 0.023,	Signal Variance: 1.698,	Lengthscale: 1.990, Graphbandwidth: 1.564
# Iteration: 492, Loss: 130.378, Lr: 0.1,	Noise Variance: 0.023,	Signal Variance: 1.704,	Lengthscale: 1.992, Graphbandwidth: 1.563
# Iteration: 493, Loss: 130.340, Lr: 0.1,	Noise Variance: 0.023,	Signal Variance: 1.711,	Lengthscale: 1.994, Graphbandwidth: 1.563
# Iteration: 494, Loss: 130.302, Lr: 0.1,	Noise Variance: 0.023,	Signal Variance: 1.718,	Lengthscale: 1.997, Graphbandwidth: 1.562
# Iteration: 495, Loss: 130.264, Lr: 0.1,	Noise Variance: 0.023,	Signal Variance: 1.725,	Lengthscale: 1.999, Graphbandwidth: 1.561
# Iteration: 496, Loss: 130.226, Lr: 0.1,	Noise Variance: 0.023,	Signal Variance: 1.732,	Lengthscale: 2.002, Graphbandwidth: 1.561
# Iteration: 497, Loss: 130.188, Lr: 0.1,	Noise Variance: 0.023,	Signal Variance: 1.738,	Lengthscale: 2.004, Graphbandwidth: 1.560
# Iteration: 498, Loss: 130.150, Lr: 0.1,	Noise Variance: 0.022,	Signal Variance: 1.745,	Lengthscale: 2.007, Graphbandwidth: 1.559
# Iteration: 499, Loss: 130.111, Lr: 0.1,	Noise Variance: 0.022,	Signal Variance: 1.752,	Lengthscale: 2.009, Graphbandwidth: 1.559
# Iteration: 500, Loss: 130.073, Lr: 0.1,	Noise Variance: 0.022,	Signal Variance: 1.759,	Lengthscale: 2.012, Graphbandwidth: 1.558

# %%
if load_vanilla_model:
    model_vanilla.load_state_dict(torch.load('../models/srmnist_vanilla_supervised.pth' if single_digit else '../models/rmnist_vanilla_supervised.pth'))
if train_vanilla_model:
    optimizer_vanilla = torch.optim.Adam(model_vanilla.parameters(), lr=1e-1, weight_decay=0.0)
    scheduler_vanilla = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer_vanilla, mode='min', factor=0.5, patience=100, threshold=1e-3, 
                                                                   threshold_mode='rel', cooldown=0, min_lr=0, eps=1e-8, verbose=False)
    loss = vanilla_train(model_vanilla, optimizer_vanilla, max_iter=500, max_cholesky=1000, tolerance=1e-2, cg_tolerance=1e-2, cg_max_iter=1000, 
                         scheduler=scheduler_vanilla, verbose=True)
    if save_vanilla_model:
        torch.save(model_vanilla.state_dict(), '../models/srmnist_vanilla_supervised.pth' if single_digit else '../models/rmnist_vanilla_supervised.pth')

# %% [markdown]
# ## Evaluation

# %%
rmse_vanilla, nll_vanilla = test_model(model_vanilla, test_x, test_y, noisy_test=True, base_model=None, max_cholesky=1000, cg_tolerance=1e-2, cg_iterations=1000)
print("RMSE Vanilla: ", rmse_vanilla)
print("NLL Vanilla: ", nll_vanilla)
# Out:
# RMSE Vanilla:  tensor(0.2784, device='cuda:0')
# NLL Vanilla:  tensor(-2.6679, device='cuda:0')

# %%
rmse, nll = test_model(model, test_x, test_y, noisy_test=True, base_model=model_vanilla, max_cholesky=1000, cg_tolerance=1e-2, cg_iterations=1000)
print("RMSE Geometric: ", rmse)
print("NLL Geometric: ", nll)
# Out:
# RMSE Geometric:  tensor(0.2981, device='cuda:0')
# NLL Geometric:  tensor(0.5420, device='cuda:0')
